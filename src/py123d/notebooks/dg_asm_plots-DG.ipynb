# %% [markdown]
# # Extract dataframe
#
# In order to mimick dg_transport, benchmark use zero_time_step and 4 calls of update_solution.
# Therefore initially there were two items for every group. One with n_calls==1 (zero_time_step)
# and one with n_calls=4 (4 x update_solution). The loading script has been hacked to skip "ZERO-TIME STEP" tag
# However all tags excepting "full_mesh" are called in 4 assembly loops.

# %%
#print(profiler_files)

# %%
# zip archive or pattern
# TODO: parametrize by assembly class names ?
profiler_files="dg_asm.zip"
profiler_files="24_10_21_dg_asm.zip"
#profiler_files="../../../bin/benchmark/dg_asm-1-bench_profiler_*.json"

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
import dg_asm_bench_postprocess as bp

# load and process Profiler JSON output
df_orig = df = bp.load_profiler_data(profiler_files)

from IPython.display import Markdown, display
    
def table_overview(df):
    for col in df.columns:
        unique = df[col].unique()
        is_factor =  all([type(v) is str for v in unique])
        value_set = np.sort(unique)
        np.set_printoptions(threshold=30)
        value_set = np.array2string(value_set, precision=2, separator=',')
        display(Markdown(f'**{col}**: {value_set}'))
                

table_overview(df_orig)
# Out:
# Input profiler files:  [Path('24_10_21_dg_asm.zip', 'dg_asm-1-bench_profiler_1.json'), Path('24_10_21_dg_asm.zip', 'dg_asm-1-bench_profiler_2.json'), Path('24_10_21_dg_asm.zip', 'dg_asm-1-bench_profiler_3.json'), Path('24_10_21_dg_asm.zip', 'dg_asm-1-bench_profiler_4.json')]
# **branch**: ['DF_patch_fe_mechanics']
# **commit**: ['c13f069']
# **run_id**: [0,1,2,3]
# **domain_shape**: ['B','L']
# **mesh_size**: ['L','M','S']
# **spacedim**: ['2D','3D']
# **uniformity**: ['refined','uniform']
# **n_mesh_elements**: [  2770.,  2806.,  2889.,  2918.,  3041.,  3046.,  3049.,  3392., 29250.,
#   29346., 30046., 30168., 30186., 30574., 31423., 31914.,301689.,302320.,
#  304838.,305121.,305984.,308574.,310479.,316110.]
# **n_repeats**: [ 1,10]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Mass','Sources','Stiffness']
# **tag**: ['MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'add_integrals_to_patch','assemble_fluxes_boundary',
#  'assemble_fluxes_elem_elem','assemble_fluxes_elem_side',
#  'assemble_volume_integrals','cache_update','create_patch','full_mesh',
#  'patch_reinit']
# **number_of_calls**: [      1,      4,     10,...,1298992,1301748,1309856]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [5.41e-05,5.41e-05,5.45e-05,...,6.57e+01,6.59e+01,6.60e+01]
# **time_fraction**: [1.25e-04,1.25e-04,1.28e-04,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0.01,0.01,0.01,...,0.15,0.15, nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'assembly']
# **level**: [5,8,9]

# %% [markdown]
# # Basic dataset modifications
# - rename some columns
# - extract `branch` and `commit` columns into `flow123d_version` variable, drop these columns
# - fix `n_el` type
# - merge `shape` and `uniformity` columns
# - Divide 'time' and 'number_of_calls' by 'n_repeats'

# %%
# Get benchmarked sources version.
df = df_orig.copy()
assert df['branch'].nunique() == 1
assert df['commit'].nunique() == 1
flow123d_version = f"{df['branch'].loc[0]}_{df['commit'].loc[0]}"
print("Benchmarked Flow123d version: ", flow123d_version)
df.drop(columns=["branch", "commit"], inplace=True)

# rename some columns:
col_map = dict(spacedim='dim', mesh_size='size', domain_shape='shape', n_mesh_elements='n_el', 
               number_of_calls='n_calls')
df.rename(columns=col_map, inplace=True)

# int values for 'n_el', 'n_calls' columns
df['n_el'] = df['n_el'].astype(int)

# merge mesh shape and uniformity
df['mesh_type'] = [f"{row['shape']}_{row['uniformity']}" for index, row in df.iterrows()]
df.drop(columns=["shape", "uniformity"], inplace=True)

def apply_n_repeats(df):
    repeated_cols = ['n_calls', 'time']
    for c in repeated_cols:
        df[c] /= df['n_repeats']
    df['n_calls'] = df['n_calls'].astype(int)
    df.drop(columns=['n_repeats'], inplace=True)
    return df

df = apply_n_repeats(df)


table_overview(df)
# Out:
# Benchmarked Flow123d version:  DF_patch_fe_mechanics_c13f069
# **run_id**: [0,1,2,3]
# **size**: ['L','M','S']
# **dim**: ['2D','3D']
# **n_el**: [  2770,  2806,  2889,  2918,  3041,  3046,  3049,  3392, 29250, 29346,
#   30046, 30168, 30186, 30574, 31423, 31914,301689,302320,304838,305121,
#  305984,308574,310479,316110]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Mass','Sources','Stiffness']
# **tag**: ['MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'add_integrals_to_patch','assemble_fluxes_boundary',
#  'assemble_fluxes_elem_elem','assemble_fluxes_elem_side',
#  'assemble_volume_integrals','cache_update','create_patch','full_mesh',
#  'patch_reinit']
# **n_calls**: [      1,      4,    112,...,1298992,1301748,1309856]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [5.46e-06,5.46e-06,5.53e-06,...,6.57e+01,6.59e+01,6.60e+01]
# **time_fraction**: [1.25e-04,1.25e-04,1.28e-04,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0.01,0.01,0.01,...,0.15,0.15, nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'assembly']
# **level**: [5,8,9]
# **mesh_type**: ['B_refined','B_uniform','L_refined','L_uniform']

# %% [markdown]
# # Mesh times comparison
# - plot `full_mesh` time for mesh and run ID variants.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def mesh_cases_plot(df, time_label):
    cases_cols = ['dim_size', 'mesh_type', 'run_id', 'variant']
    stacked_df = df.groupby(cases_cols)['time'].sum().unstack('variant').fillna(0)
    n_rows = len(stacked_df)
    
    # for grouping by position on Y axis
    level_labels = [l for l in stacked_df.index.levels]
    level_vals = [pd.Categorical(l).codes for l in stacked_df.index.levels]
    int_df = stacked_df.copy()
    int_df.index = stacked_df.index.set_levels(level_vals, level=[0, 1, 2])

    bar_width = 0.5
    steps = []
    ticks = []
    tick_labels = []
    last_idx = (0,-1,-1)
    step = np.array([0.5, 0.5, bar_width])
    for idx in int_df.index.drop_duplicates():
        diff = np.array(idx) - np.array(last_idx)
        last_idx = idx
        if diff[1] != 0:
            ticks.append(len(steps))
            tick_labels.append(f'{level_labels[0][idx[0]]}, {level_labels[1][idx[1]]: >12}')
        steps.append(np.sum(step[diff != 0]))
        
    positions = np.cumsum(steps)
    ticks = positions[ticks]        
    
    # Initialize a color palette
    palette = sns.color_palette("tab10", len(stacked_df.columns))
    
    # Plotting
    fig, ax = plt.subplots(figsize=(10, 6))
  
    # Create stacked bars
    bottom = np.zeros(n_rows)
    for j, col in enumerate(stacked_df.columns):
            ax.barh(positions, stacked_df[col], bar_width, left=bottom, color=palette[j], label=col)
            bottom += stacked_df[col]
    
    ax.set_yticks(ticks)
    ax.set_yticklabels(tick_labels)
    ax.legend(title='Assembly Variants')
    ax.set_xlabel(time_label)
    ax.set_ylabel('Mesh variants: dim_size, shape_refine')
    ax.set_title(f'Overview of benchmark: {flow123d_version}')
    
    # Display
    fig.tight_layout()
    plt.show()
    return fig
    

df_sumrun = df[df['tag'] == 'full_mesh'].copy()
df_sumrun['dim_size'] = df_sumrun['dim'] + '_' + df_sumrun['size']
def variant(row):
    var = row['assembly_variant']
    if var == 'EvalFields':
        var = f"Fields_{row['field_variant']}"
    return var

df_sumrun['variant'] = df.apply(variant, axis=1)
fig = mesh_cases_plot(df_sumrun, 'Time [s]')

# %% [markdown]
# ## Relative Mesh comparison
# Comparison of time per element allows us to see:
#
# - nearly no difference between mesh sizes, i.e., almost zero assembly overhead or
#   additional 'fit to the cache' advantages of small meshes.
#   Fitting all to the cache probably could not happen as individual data are allocated at different places.
#   It seems more probable that even for small meshes (S ~ 1000 elements)
#   the calculation has some cache misses. Needs better investigation.
#
# - significant impact of 3D calculation. 3D has about 4/3 times more DOFs, the increase is slightly higher,
#   possibly due to a larger increase in the number of quadrature points o
#
# - very small impact of `mesh_type`
#
# - the significant impact of `run_id` we should rather increase the number of runs to 5. Memory layout could
#   have some impact. Ideally, we should minimize this impact by own arena allocator used for
#   assembly structures on the patch.

# %%
df_reltime = df_sumrun.copy()
df_reltime['time'] = df_reltime['time'] / df_reltime['n_el'] * 1000
fig = mesh_cases_plot(df_reltime, 'Time per 1000 element [s]')
fig.savefig("overview_plot.pdf")

# %% [markdown]
# # Aggregate runs
# - compute suitable position and variance indicators
# - report (tags) with high variability and high time fraction
#
# Se that there is much higher `run_ID` variability at a detailed level and even for long time frames.

# %%
index_cols = ['dim', 'mesh_type', 'size', 'assembly_variant', 'field_variant', 'assembly_class', 'integral_type', 'tag']
grouped = df.groupby(index_cols)
#print(grouped.size())
n_runs = len(df['run_id'].unique())
assert all(grouped.size() == n_runs)
# Available groups
# print(grouped.groups.keys())
# Rows in a single group:
# display(grouped.get_group(('2D', 'B_refined', 'L', 'ComputeLocal', 'model', 'Mass', '', 'MassAssembly')))

def get_median_row(group):
    min_t = group['time'].min()
    median_t = group['time'].median()
    max_t = group['time'].max()
    row = group[group['time'] == min_t]
    row['Err'] = (median_t - min_t) / min_t
    return row

# Apply the custom function to each group
df_med = grouped.apply(get_median_row).reset_index(drop=True)
#display(result)
df_med.drop(columns=['run_id'], inplace=True)
df_med.drop(columns=['n_calls', 'integral_type', 'n_el', 'time_fraction_of_reminder', 'parent_tag', 'level'], inplace=True)

# Sort the DataFrame by column 'A'
# There are many items with big error and big time fraction.
sorted_df = df_med.sort_values(by='Err', ascending=False)
big_err = sorted_df[sorted_df['Err'] > 0.1]
big_err_and_fraction = big_err[big_err['time_fraction'] > 0.05]
# Display the sorted DataFrame
display(big_err_and_fraction.head(30))


# Result kee run_id and try to plot all three values in plots.
# Out:
#      size dim field_variant assembly_variant assembly_class  \
# 916     S  2D         model     ComputeLocal      Stiffness
# 1000    S  2D         model     FullAssembly      Stiffness
#
#                          tag      time  time_fraction  mesh_type       Err
# 916   add_integrals_to_patch  0.010906       0.067032  L_refined  0.132057
# 1000  add_integrals_to_patch  0.011091       0.060599  L_refined  0.119984

# %% [markdown]
# # Detailed view
#
# 1. reduce assembly variants to new tags having complete decomposition of a single assembly
# 2. separate plot for each `assembly_class`
# 3. group by:
#    `dim_size`, `tag`
# 4. in every group points from: reduction, runs, mesh_type `

# %%
# reduce columns: assembly_variant, field_variant, integral_type
# to tags: 
# field_const, field_model
# <integral>_loop, <integral>_local, <integral>_global
# reminder (of assembly)

new_rows = {}

def add_row(group, orig_row_mask, tag, time_subtrack):
    """
    Add new row to the dataset by taking `orig_row_mask` from `group`
    setting the `tag` and subtrack `time_subtrack` from the `time` column.
    We return original `time` value.
    """
    orig = group[orig_row_mask].to_dict('list')
    orig_time = np.mean(orig['time'])
    for i in range(len(orig['time'])):
        #print(new_row)
        orig['time'][i] -= time_subtrack
        orig['tag'][i] = tag
    for key, item_dict in orig.items():
        col = new_rows.setdefault(key, [])
        col.extend(item_dict)
    return orig_time
    

# check same time of some tags between variants
index_cols = ['run_id', 'dim', 'mesh_type', 'size',  'assembly_class']
grouped = df.groupby(index_cols)

# Add column with assembly total times
#
for name, group in grouped:
    # skip full_mesh group
    if name[-1] == '':
        assert all(group['tag'] == 'full_mesh')
        continue
    main_tag = f"{name[-1]}Assembly"
    asm_var = group['assembly_variant']    
    field_var = group['field_variant']
    tags = group['tag']
    integral = group['integral_type']

    # compute reminders
    reminders = {
        'field_const':('EvalFields', 'const'),
        'field_model':('EvalFields', 'model'),
        'local': ('ComputeLocal', 'model'),
        'global': ('FullAssembly', 'model'),}
    rm = {}
    for key, (av, fv) in reminders.items():
        subgroup = group[(asm_var == av) & (field_var == fv)]
        assembly_time = subgroup[subgroup['tag'] == main_tag]['time'].item()
        total = np.sum(subgroup['time']) - assembly_time
        reminder = assembly_time - total
        rm[key] = reminder #, reminder/total)
    rm_mean = np.mean(list(rm.values()))
    rm_std = np.std(list(rm.values()))
    print(f"{repr(name):<40}  reminder: {rm_mean:<10.5} sd: {300*rm_std/rm_mean:3.0f}%")
            
    
    # Patch creation
    add_row(group, tags == 'add_integrals_to_patch', 'colect_patch', 0.0)
    add_row(group, tags == 'create_patch', 'create_patch', 0.0)
    # Fields - Cache Update
    field_const_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'const')
    t_field_const = add_row(group, field_const_mask, 'field_const', 0.0)
    field_model_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'model')
    add_row(group, field_model_mask, 'field_model',  t_field_const)

    # Assembly integrals
    for it in integral.unique():
        if it == '':
            continue
        loop_mask = (asm_var == 'EvalFields') & (integral == it)
        t_loop = add_row(group, loop_mask, f'{it}_loop', 0.0)
        local_mask = (asm_var == 'ComputeLocal') & (integral == it)
        t_local = add_row(group, local_mask, f'{it}_local', t_loop)
        global_mask = (asm_var == 'FullAssembly') & (integral == it)
        add_row(group, global_mask, f'{it}_global', t_local)
    
    # Reminder - taking mean value, bute there could be huge deviances, but mostly for small values    
    assembly_mask = (asm_var == 'FullAssembly') & (tags == main_tag)
    mod_group = group[assembly_mask].copy()
    mod_group['time'] = rm_mean
    add_row(mod_group, mod_group['time'] == mod_group['time'], 'reminder', 0.0)
    
detail_df = pd.DataFrame(new_rows)
#table_overview(detail_df)
display(detail_df)
# Out:
# (0, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.1011     sd:   2%
# (0, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.099805   sd:   2%
# (0, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.15268    sd:  14%
# (0, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.010084   sd:   3%
# (0, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.0097371  sd:   4%
# (0, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.016072   sd:  24%
# (0, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.0012798  sd:  40%
# (0, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.00099534 sd:   1%
# (0, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0030589  sd:  92%
# (0, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.10157    sd:   1%
# (0, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.10096    sd:   3%
# (0, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.15152    sd:  11%
# (0, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.010378   sd:   8%
# (0, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.0099687  sd:   4%
# (0, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.016498   sd:  24%
# (0, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.001315   sd:  37%
# (0, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.0010383  sd:   3%
# (0, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0031017  sd:  90%
# (0, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.10482    sd:   2%
# (0, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.10429    sd:   2%
# (0, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.15811    sd:  12%
# (0, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.011944   sd:  82%
# (0, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0096647  sd:   2%
# (0, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.01625    sd:  25%
# (0, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.0012973  sd:  48%
# (0, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00096753 sd:   6%
# (0, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0030327  sd:  94%
# (0, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.09992    sd:   0%
# (0, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.099058   sd:   2%
# (0, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.15162    sd:  12%
# (0, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.010373   sd:   7%
# (0, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.0099294  sd:   1%
# (0, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.016684   sd:  24%
# (0, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.0012459  sd:  41%
# (0, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00096699 sd:   5%
# (0, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0030052  sd:  94%
# (0, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.10731    sd:   3%
# (0, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.1071     sd:   5%
# (0, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.21752    sd:  13%
# (0, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.011151   sd:   5%
# (0, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.010619   sd:   2%
# (0, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.02347    sd:  24%
# (0, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.0014135  sd:  40%
# (0, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.0011239  sd:   6%
# (0, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0038286  sd:  78%
# (0, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.10994    sd:   3%
# (0, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.10996    sd:   3%
# (0, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.21386    sd:  13%
# (0, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.011411   sd:   8%
# (0, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.011225   sd:   8%
# (0, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.023382   sd:  25%
# (0, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.0015394  sd:  38%
# (0, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.0012466  sd:   4%
# (0, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0040326  sd:  74%
# (0, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.10867    sd:   4%
# (0, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.10749    sd:   4%
# (0, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.21911    sd:  12%
# (0, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.011274   sd:   9%
# (0, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.010902   sd:   4%
# (0, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.023264   sd:  25%
# (0, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0014274  sd:  41%
# (0, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.0011356  sd:   8%
# (0, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0037888  sd:  78%
# (0, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.1093     sd:   2%
# (0, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.10871    sd:   5%
# (0, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.21222    sd:  15%
# (0, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.011724   sd:   8%
# (0, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.011313   sd:   3%
# (0, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.024043   sd:  23%
# (0, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.0013862  sd:  39%
# (0, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.0010702  sd:   4%
# (0, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0036871  sd:  80%
# (1, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.10275    sd:   4%
# (1, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.10099    sd:   4%
# (1, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.1534     sd:  12%
# (1, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.0101     sd:   9%
# (1, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.009807   sd:   3%
# (1, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.016111   sd:  23%
# (1, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.0012838  sd:  41%
# (1, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.001004   sd:   2%
# (1, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0030874  sd:  93%
# (1, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.10192    sd:   3%
# (1, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.10232    sd:   3%
# (1, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.15306    sd:  11%
# (1, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.010403   sd:   7%
# (1, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.01018    sd:   7%
# (1, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.016576   sd:  25%
# (1, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.0013168  sd:  40%
# (1, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.0010435  sd:   5%
# (1, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0031107  sd:  91%
# (1, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.10575    sd:   4%
# (1, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.10505    sd:   3%
# (1, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.15894    sd:  12%
# (1, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.01016    sd:   9%
# (1, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0097012  sd:   3%
# (1, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.016555   sd:  18%
# (1, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.0012334  sd:  42%
# (1, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00095124 sd:   2%
# (1, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0030108  sd:  94%
# (1, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.1005     sd:   3%
# (1, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.10112    sd:   7%
# (1, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.15046    sd:  12%
# (1, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.010456   sd:  10%
# (1, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.010064   sd:   5%
# (1, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.016623   sd:  23%
# (1, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.0012519  sd:  37%
# (1, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00096427 sd:   5%
# (1, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0030065  sd:  93%
# (1, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.10776    sd:   4%
# (1, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.10631    sd:   3%
# (1, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.21851    sd:  16%
# (1, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.010985   sd:   7%
# (1, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.010633   sd:   2%
# (1, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.023267   sd:  25%
# (1, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.001425   sd:  42%
# (1, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.0011171  sd:   5%
# (1, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0038189  sd:  78%
# (1, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.10991    sd:   3%
# (1, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.10966    sd:   2%
# (1, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.21309    sd:  18%
# (1, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.011513   sd:   8%
# (1, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.011113   sd:   3%
# (1, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.023433   sd:  21%
# (1, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.0015429  sd:  38%
# (1, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.0012439  sd:   7%
# (1, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0040546  sd:  74%
# (1, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.10852    sd:   3%
# (1, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.10767    sd:   3%
# (1, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.21714    sd:  14%
# (1, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.011188   sd:   6%
# (1, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.010778   sd:   4%
# (1, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.023482   sd:  26%
# (1, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0014463  sd:  42%
# (1, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.0011229  sd:   5%
# (1, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0038359  sd:  79%
# (1, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.10979    sd:   1%
# (1, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.10992    sd:   2%
# (1, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.21245    sd:  13%
# (1, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.011681   sd:   8%
# (1, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.011224   sd:   2%
# (1, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.024228   sd:  22%
# (1, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.001389   sd:  45%
# (1, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.001066   sd:   5%
# (1, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0037417  sd:  80%
# (2, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.10073    sd:   3%
# (2, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.1003     sd:   2%
# (2, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.1534     sd:  12%
# (2, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.010046   sd:   8%
# (2, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.0097903  sd:   5%
# (2, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.016364   sd:  26%
# (2, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.0013071  sd:  45%
# (2, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.0010001  sd:   4%
# (2, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0031078  sd:  93%
# (2, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.10134    sd:   4%
# (2, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.10178    sd:   3%
# (2, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.15384    sd:  11%
# (2, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.010355   sd:   9%
# (2, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.0099527  sd:   2%
# (2, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.016797   sd:  26%
# (2, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.0014059  sd:  49%
# (2, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.0010643  sd:   6%
# (2, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0031872  sd:  93%
# (2, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.10448    sd:   2%
# (2, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.10427    sd:   4%
# (2, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.16061    sd:   9%
# (2, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.01001    sd:   9%
# (2, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0098365  sd:   4%
# (2, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.016653   sd:  26%
# (2, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.001272   sd:  47%
# (2, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00095874 sd:   5%
# (2, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0030186  sd:  95%
# (2, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.099532   sd:   3%
# (2, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.099194   sd:   2%
# (2, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.15314    sd:  12%
# (2, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.010332   sd:   7%
# (2, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.0099439  sd:   2%
# (2, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.016803   sd:  24%
# (2, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.0012813  sd:  46%
# (2, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00097151 sd:   5%
# (2, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0030402  sd:  95%
# (2, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.10654    sd:   3%
# (2, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.10539    sd:   1%
# (2, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.221      sd:  17%
# (2, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.010919   sd:   8%
# (2, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.010919   sd:  16%
# (2, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.0237     sd:  23%
# (2, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.0014629  sd:  44%
# (2, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.0011211  sd:   4%
# (2, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0038848  sd:  78%
# (2, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.11142    sd:   6%
# (2, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.10867    sd:   1%
# (2, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.21569    sd:  14%
# (2, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.011561   sd:   9%
# (2, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.01102    sd:   1%
# (2, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.02377    sd:  21%
# (2, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.0016022  sd:  43%
# (2, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.0012525  sd:   7%
# (2, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0041394  sd:  75%
# (2, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.10859    sd:   1%
# (2, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.10803    sd:   7%
# (2, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.21801    sd:  15%
# (2, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.011168   sd:  10%
# (2, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.010736   sd:   3%
# (2, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.023225   sd:  20%
# (2, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0014073  sd:  39%
# (2, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.0011094  sd:   3%
# (2, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0038182  sd:  79%
# (2, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.10873    sd:   2%
# (2, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.10783    sd:   2%
# (2, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.21378    sd:  12%
# (2, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.011559   sd:   7%
# (2, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.011161   sd:   2%
# (2, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.024133   sd:  23%
# (2, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.0013758  sd:  45%
# (2, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.0010648  sd:   5%
# (2, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0037007  sd:  80%
# (3, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.10072    sd:   1%
# (3, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.1001     sd:   2%
# (3, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.1578     sd:  12%
# (3, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.010048   sd:   8%
# (3, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.0097762  sd:   6%
# (3, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.016143   sd:  25%
# (3, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.0012701  sd:  40%
# (3, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.00099541 sd:   2%
# (3, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0030816  sd:  91%
# (3, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.10124    sd:   1%
# (3, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.10042    sd:   2%
# (3, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.15306    sd:  11%
# (3, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.010369   sd:   9%
# (3, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.010062   sd:   4%
# (3, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.016648   sd:  25%
# (3, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.0013278  sd:  41%
# (3, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.0010412  sd:   5%
# (3, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0031274  sd:  92%
# (3, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.10476    sd:   1%
# (3, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.10388    sd:   2%
# (3, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.15949    sd:  12%
# (3, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.010041   sd:   8%
# (3, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0096773  sd:   2%
# (3, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.016355   sd:  27%
# (3, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.00127    sd:  46%
# (3, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00095829 sd:   4%
# (3, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0030445  sd:  94%
# (3, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.10061    sd:   3%
# (3, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.099799   sd:   2%
# (3, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.15648    sd:  16%
# (3, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.010305   sd:   7%
# (3, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.010031   sd:   2%
# (3, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.01683    sd:  26%
# (3, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.0012872  sd:  46%
# (3, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00097683 sd:   3%
# (3, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0030427  sd:  95%
# (3, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.10662    sd:   2%
# (3, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.10642    sd:   3%
# (3, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.22199    sd:  19%
# (3, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.011064   sd:   2%
# (3, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.010877   sd:   8%
# (3, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.023632   sd:  28%
# (3, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.0014649  sd:  44%
# (3, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.0011352  sd:   5%
# (3, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0038919  sd:  78%
# (3, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.11014    sd:   2%
# (3, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.10939    sd:   2%
# (3, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.2179     sd:  13%
# (3, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.01156    sd:  11%
# (3, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.011125   sd:   1%
# (3, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.023482   sd:  22%
# (3, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.0015917  sd:  41%
# (3, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.0012468  sd:   6%
# (3, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0040911  sd:  76%
# (3, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.10797    sd:   1%
# (3, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.108      sd:   3%
# (3, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.21831    sd:  14%
# (3, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.011117   sd:   7%
# (3, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.010878   sd:   4%
# (3, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.023466   sd:  24%
# (3, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0014     sd:  39%
# (3, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.0011097  sd:   4%
# (3, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0037891  sd:  78%
# (3, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.10997    sd:   2%
# (3, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.10835    sd:   2%
# (3, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.21446    sd:  14%
# (3, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.011594   sd:   7%
# (3, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.011193   sd:   3%
# (3, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.024201   sd:  26%
# (3, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.0013348  sd:  40%
# (3, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.0010512  sd:   4%
# (3, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0036822  sd:  80%
#       run_id size dim    n_el field_variant assembly_variant assembly_class  \
# 0          0    L  2D  304838         model     FullAssembly           Mass
# 1          0    L  2D  304838         model     ComputeLocal           Mass
# 2          0    L  2D  304838         const       EvalFields           Mass
# 3          0    L  2D  304838         model       EvalFields           Mass
# 4          0    L  2D  304838         model     FullAssembly           Mass
# ...      ...  ...  ..     ...           ...              ...            ...
# 7771       3    S  3D    2889         const       EvalFields      Stiffness
# 7772       3    S  3D    2889         model       EvalFields      Stiffness
# 7773       3    S  3D    2889         model     ComputeLocal      Stiffness
# 7774       3    S  3D    2889         model     FullAssembly      Stiffness
# 7775       3    S  3D    2889         model     FullAssembly      Stiffness
#
#                  tag  n_calls integral_type          time  time_fraction  \
# 0       colect_patch  1219352                2.375588e-01       0.100024
# 1       colect_patch  1219352                2.263736e-01       0.109105
# 2       colect_patch  1219352                2.247976e-01       0.320608
# 3       colect_patch  1219352                2.283121e-01       0.210973
# 4       create_patch    12320                9.637099e-02       0.040577
# ...              ...      ...           ...           ...            ...
# 7771    dimjoin_loop      696       dimjoin  3.801250e-05       0.000478
# 7772    dimjoin_loop      696       dimjoin  3.981760e-05       0.000242
# 7773   dimjoin_local      696       dimjoin  1.502245e-05       0.000163
# 7774  dimjoin_global      696       dimjoin  1.834000e-07       0.000146
# 7775        reminder        4                3.682232e-03       0.806862
#
#       time_fraction_of_reminder         parent_tag  level  mesh_type
# 0                           NaN       MassAssembly      9  B_refined
# 1                           NaN       MassAssembly      9  B_refined
# 2                           NaN       MassAssembly      9  B_refined
# 3                           NaN       MassAssembly      9  B_refined
# 4                           NaN       MassAssembly      9  B_refined
# ...                         ...                ...    ...        ...
# 7771                        NaN  StiffnessAssembly      9  L_uniform
# 7772                        NaN  StiffnessAssembly      9  L_uniform
# 7773                        NaN  StiffnessAssembly      9  L_uniform
# 7774                        NaN  StiffnessAssembly      9  L_uniform
# 7775                   0.011672           assembly      8  L_uniform
#
# [7776 rows x 16 columns]

# %%
ddf = detail_df.copy()
ddf['dim_size'] = ddf['dim'] + '_' + ddf['size']
ddf['time'] = ddf['time'] / ddf['n_el']
#ddf.set_index(['assembly_class'], inplace=True)
#print(ddf.columns)
#print(detail_df['assembly_class'])

# Define custom colors matching structure of `dim_size` values
cold_tones = ['#5F3EA0', '#6495ED', '#00CED1'] 
warm_tones = ['#a42d14', '#ff5308', '#f0f03a', ] 
custom_palette = cold_tones + warm_tones
sns.set_palette(custom_palette)

assembly_classes = ddf['assembly_class'].unique()
print(assembly_classes)

facet_grid = sns.catplot(data=ddf, x='time', y='tag', hue='dim_size', row='assembly_class',
            kind='strip', orient='h', sharex=False, aspect=2, jitter=0.25, size=3,
            row_order=assembly_classes,
            legend_out=False)

handles, labels = facet_grid.axes[2][0].get_legend_handles_labels()
#print(handles, labels)
for ax, loc in zip(facet_grid.axes.flatten(), [1,4,4]):
    ax.legend(handles, labels, loc=loc)
facet_grid.axes[2][0].set_xlabel("Time per element")
facet_grid.fig.subplots_adjust(top=0.93) # adjust the Figure in rp
facet_grid.fig.suptitle(f'Detailed view of: {flow123d_version}')

plt.savefig("detailed_plot.pdf")
# Out:
# ['Mass' 'Sources' 'Stiffness']

# %% [markdown]
# ## Interpretation
#
# ### Patch creation
# - patch creation overhead is relatively small, comparable to field_model evaluation for matrix assemblies
# - the overhead is much more significant for simple assembly like `Sources`
# - the overhead in field evaluation and field access is not included, so in fact, the overhead could be higher 1.5 times
#
# ### Field evaluation
# - It seems that evaluation of tensor-valued fields necessary in `Stiffness` is much more costly. Also, different kinds of fields are possibly in use.
# - Constant value fields have negligible evaluation time.
#
# ### Assembly
# - `<integral>_global` are calculated from noisy `<integral>_local` values, so it is noisy as well, leading to even negative values for fast vector-only assembly of `Sources`.
# - Nevertheless, it is relatively costly for `Stiffness` and clearly correlated to the number of calls since it is higher for 3d meshes.
# - Local evaluations are the highest in all three cases. Probably dominated by `FEValues.reinit` (according to VTUNE analysis).
