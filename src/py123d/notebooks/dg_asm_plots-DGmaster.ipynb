# %% [markdown]
# # Extract dataframe
#
# In order to mimick dg_transport, benchmark use zero_time_step and 4 calls of update_solution.
# Therefore initially there were two items for every group. One with n_calls==1 (zero_time_step)
# and one with n_calls=4 (4 x update_solution). The loading script has been hacked to skip "ZERO-TIME STEP" tag
# However all tags excepting "full_mesh" are called in 4 assembly loops.

# %%
#print(profiler_files)

# %%
# zip archive or pattern
# TODO: parametrize by assembly class names ?
profiler_files="dg_asm.zip"
profiler_files="24_10_21_dg_asm_master.zip"
#profiler_files="../../../bin/benchmark/dg_asm-1-bench_profiler_*.json"

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
import dg_asm_bench_postprocess as bp

# load and process Profiler JSON output
df_orig = df = bp.load_profiler_data(profiler_files)

from IPython.display import Markdown, display
    
def table_overview(df):
    for col in df.columns:
        unique = df[col].unique()
        is_factor =  all([type(v) is str for v in unique])
        value_set = np.sort(unique)
        np.set_printoptions(threshold=30)
        value_set = np.array2string(value_set, precision=2, separator=',')
        display(Markdown(f'**{col}**: {value_set}'))
                

table_overview(df_orig)
# Out:
# Input profiler files:  [Path('24_10_21_dg_asm_master.zip', 'dg_asm-1-bench_profiler_1.json'), Path('24_10_21_dg_asm_master.zip', 'dg_asm-1-bench_profiler_2.json'), Path('24_10_21_dg_asm_master.zip', 'dg_asm-1-bench_profiler_3.json'), Path('24_10_21_dg_asm_master.zip', 'dg_asm-1-bench_profiler_4.json')]
# **branch**: ['DF_mechanic_bench']
# **commit**: ['4ba6315']
# **run_id**: [0,1,2,3]
# **domain_shape**: ['B','L']
# **mesh_size**: ['L','M','S']
# **spacedim**: ['2D','3D']
# **uniformity**: ['refined','uniform']
# **n_mesh_elements**: [  2770.,  2806.,  2889.,  2918.,  3041.,  3046.,  3049.,  3392., 29250.,
#   29346., 30046., 30168., 30186., 30574., 31423., 31914.,301689.,302320.,
#  304838.,305121.,305984.,308574.,310479.,316110.]
# **n_repeats**: [ 1,10]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Mass','Sources','Stiffness']
# **tag**: ['MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'add_integrals_to_patch','assemble_fluxes_boundary',
#  'assemble_fluxes_elem_elem','assemble_fluxes_elem_side',
#  'assemble_volume_integrals','cache_update','create_patch','full_mesh']
# **number_of_calls**: [      1,      4,     10,...,1298992,1301748,1309856]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [5.42e-05,5.44e-05,5.44e-05,...,5.97e+01,5.99e+01,5.99e+01]
# **time_fraction**: [1.27e-04,1.31e-04,1.31e-04,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0.01,0.01,0.01,...,0.2 ,0.2 , nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'assembly']
# **level**: [5,8,9]

# %% [markdown]
# # Basic dataset modifications
# - rename some columns
# - extract `branch` and `commit` columns into `flow123d_version` variable, drop these columns
# - fix `n_el` type
# - merge `shape` and `uniformity` columns
# - Divide 'time' and 'number_of_calls' by 'n_repeats'

# %%
# Get benchmarked sources version.
df = df_orig.copy()
assert df['branch'].nunique() == 1
assert df['commit'].nunique() == 1
flow123d_version = f"{df['branch'].loc[0]}_{df['commit'].loc[0]}"
print("Benchmarked Flow123d version: ", flow123d_version)
df.drop(columns=["branch", "commit"], inplace=True)

# rename some columns:
col_map = dict(spacedim='dim', mesh_size='size', domain_shape='shape', n_mesh_elements='n_el', 
               number_of_calls='n_calls')
df.rename(columns=col_map, inplace=True)

# int values for 'n_el', 'n_calls' columns
df['n_el'] = df['n_el'].astype(int)

# merge mesh shape and uniformity
df['mesh_type'] = [f"{row['shape']}_{row['uniformity']}" for index, row in df.iterrows()]
df.drop(columns=["shape", "uniformity"], inplace=True)

def apply_n_repeats(df):
    repeated_cols = ['n_calls', 'time']
    for c in repeated_cols:
        df[c] /= df['n_repeats']
    df['n_calls'] = df['n_calls'].astype(int)
    df.drop(columns=['n_repeats'], inplace=True)
    return df

df = apply_n_repeats(df)


table_overview(df)
# Out:
# Benchmarked Flow123d version:  DF_mechanic_bench_4ba6315
# **run_id**: [0,1,2,3]
# **size**: ['L','M','S']
# **dim**: ['2D','3D']
# **n_el**: [  2770,  2806,  2889,  2918,  3041,  3046,  3049,  3392, 29250, 29346,
#   30046, 30168, 30186, 30574, 31423, 31914,301689,302320,304838,305121,
#  305984,308574,310479,316110]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Mass','Sources','Stiffness']
# **tag**: ['MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'add_integrals_to_patch','assemble_fluxes_boundary',
#  'assemble_fluxes_elem_elem','assemble_fluxes_elem_side',
#  'assemble_volume_integrals','cache_update','create_patch','full_mesh']
# **n_calls**: [      1,      4,    112,...,1298992,1301748,1309856]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [5.42e-06,5.44e-06,5.44e-06,...,5.97e+01,5.99e+01,5.99e+01]
# **time_fraction**: [1.27e-04,1.31e-04,1.31e-04,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0.01,0.01,0.01,...,0.2 ,0.2 , nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'assembly']
# **level**: [5,8,9]
# **mesh_type**: ['B_refined','B_uniform','L_refined','L_uniform']

# %% [markdown]
# # Mesh times comparison
# - plot `full_mesh` time for mesh and run ID variants.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def mesh_cases_plot(df, time_label):
    cases_cols = ['dim_size', 'mesh_type', 'run_id', 'variant']
    stacked_df = df.groupby(cases_cols)['time'].sum().unstack('variant').fillna(0)
    n_rows = len(stacked_df)
    
    # for grouping by position on Y axis
    level_labels = [l for l in stacked_df.index.levels]
    level_vals = [pd.Categorical(l).codes for l in stacked_df.index.levels]
    int_df = stacked_df.copy()
    int_df.index = stacked_df.index.set_levels(level_vals, level=[0, 1, 2])

    bar_width = 0.5
    steps = []
    ticks = []
    tick_labels = []
    last_idx = (0,-1,-1)
    step = np.array([0.5, 0.5, bar_width])
    for idx in int_df.index.drop_duplicates():
        diff = np.array(idx) - np.array(last_idx)
        last_idx = idx
        if diff[1] != 0:
            ticks.append(len(steps))
            tick_labels.append(f'{level_labels[0][idx[0]]}, {level_labels[1][idx[1]]: >12}')
        steps.append(np.sum(step[diff != 0]))
        
    positions = np.cumsum(steps)
    ticks = positions[ticks]        
    
    # Initialize a color palette
    palette = sns.color_palette("tab10", len(stacked_df.columns))
    
    # Plotting
    fig, ax = plt.subplots(figsize=(10, 6))
  
    # Create stacked bars
    bottom = np.zeros(n_rows)
    for j, col in enumerate(stacked_df.columns):
            ax.barh(positions, stacked_df[col], bar_width, left=bottom, color=palette[j], label=col)
            bottom += stacked_df[col]
    
    ax.set_yticks(ticks)
    ax.set_yticklabels(tick_labels)
    ax.legend(title='Assembly Variants')
    ax.set_xlabel(time_label)
    ax.set_ylabel('Mesh variants: dim_size, shape_refine')
    ax.set_title(f'Overview of benchmark: {flow123d_version}')
    
    # Display
    fig.tight_layout()
    plt.show()
    return fig
    

df_sumrun = df[df['tag'] == 'full_mesh'].copy()
df_sumrun['dim_size'] = df_sumrun['dim'] + '_' + df_sumrun['size']
def variant(row):
    var = row['assembly_variant']
    if var == 'EvalFields':
        var = f"Fields_{row['field_variant']}"
    return var

df_sumrun['variant'] = df.apply(variant, axis=1)
fig = mesh_cases_plot(df_sumrun, 'Time [s]')

# %% [markdown]
# ## Relative Mesh comparison
# Comparison of time per element allows us to see:
#
# - nearly no difference between mesh sizes, i.e., almost zero assembly overhead or
#   additional 'fit to the cache' advantages of small meshes.
#   Fitting all to the cache probably could not happen as individual data are allocated at different places.
#   It seems more probable that even for small meshes (S ~ 1000 elements)
#   the calculation has some cache misses. Needs better investigation.
#
# - significant impact of 3D calculation. 3D has about 4/3 times more DOFs, the increase is slightly higher,
#   possibly due to a larger increase in the number of quadrature points o
#
# - very small impact of `mesh_type`
#
# - the significant impact of `run_id` we should rather increase the number of runs to 5. Memory layout could
#   have some impact. Ideally, we should minimize this impact by own arena allocator used for
#   assembly structures on the patch.

# %%
df_reltime = df_sumrun.copy()
df_reltime['time'] = df_reltime['time'] / df_reltime['n_el'] * 1000
fig = mesh_cases_plot(df_reltime, 'Time per 1000 element [s]')
fig.savefig("overview_plot.pdf")

# %% [markdown]
# # Aggregate runs
# - compute suitable position and variance indicators
# - report (tags) with high variability and high time fraction
#
# Se that there is much higher `run_ID` variability at a detailed level and even for long time frames.

# %%
index_cols = ['dim', 'mesh_type', 'size', 'assembly_variant', 'field_variant', 'assembly_class', 'integral_type', 'tag']
grouped = df.groupby(index_cols)
#print(grouped.size())
n_runs = len(df['run_id'].unique())
assert all(grouped.size() == n_runs)
# Available groups
# print(grouped.groups.keys())
# Rows in a single group:
# display(grouped.get_group(('2D', 'B_refined', 'L', 'ComputeLocal', 'model', 'Mass', '', 'MassAssembly')))

def get_median_row(group):
    min_t = group['time'].min()
    median_t = group['time'].median()
    max_t = group['time'].max()
    row = group[group['time'] == min_t]
    row['Err'] = (median_t - min_t) / min_t
    return row

# Apply the custom function to each group
df_med = grouped.apply(get_median_row).reset_index(drop=True)
#display(result)
df_med.drop(columns=['run_id'], inplace=True)
df_med.drop(columns=['n_calls', 'integral_type', 'n_el', 'time_fraction_of_reminder', 'parent_tag', 'level'], inplace=True)

# Sort the DataFrame by column 'A'
# There are many items with big error and big time fraction.
sorted_df = df_med.sort_values(by='Err', ascending=False)
big_err = sorted_df[sorted_df['Err'] > 0.1]
big_err_and_fraction = big_err[big_err['time_fraction'] > 0.05]
# Display the sorted DataFrame
display(big_err_and_fraction.head(30))


# Result kee run_id and try to plot all three values in plots.
# Out:
# Empty DataFrame
# Columns: [size, dim, field_variant, assembly_variant, assembly_class, tag, time, time_fraction, mesh_type, Err]
# Index: []

# %% [markdown]
# # Detailed view
#
# 1. reduce assembly variants to new tags having complete decomposition of a single assembly
# 2. separate plot for each `assembly_class`
# 3. group by:
#    `dim_size`, `tag`
# 4. in every group points from: reduction, runs, mesh_type `

# %%
# reduce columns: assembly_variant, field_variant, integral_type
# to tags: 
# field_const, field_model
# <integral>_loop, <integral>_local, <integral>_global
# reminder (of assembly)

new_rows = {}

def add_row(group, orig_row_mask, tag, time_subtrack):
    """
    Add new row to the dataset by taking `orig_row_mask` from `group`
    setting the `tag` and subtrack `time_subtrack` from the `time` column.
    We return original `time` value.
    """
    orig = group[orig_row_mask].to_dict('list')
    orig_time = np.mean(orig['time'])
    for i in range(len(orig['time'])):
        #print(new_row)
        orig['time'][i] -= time_subtrack
        orig['tag'][i] = tag
    for key, item_dict in orig.items():
        col = new_rows.setdefault(key, [])
        col.extend(item_dict)
    return orig_time
    

# check same time of some tags between variants
index_cols = ['run_id', 'dim', 'mesh_type', 'size',  'assembly_class']
grouped = df.groupby(index_cols)

# Add column with assembly total times
#
for name, group in grouped:
    # skip full_mesh group
    if name[-1] == '':
        assert all(group['tag'] == 'full_mesh')
        continue
    main_tag = f"{name[-1]}Assembly"
    asm_var = group['assembly_variant']    
    field_var = group['field_variant']
    tags = group['tag']
    integral = group['integral_type']

    # compute reminders
    reminders = {
        'field_const':('EvalFields', 'const'),
        'field_model':('EvalFields', 'model'),
        'local': ('ComputeLocal', 'model'),
        'global': ('FullAssembly', 'model'),}
    rm = {}
    for key, (av, fv) in reminders.items():
        subgroup = group[(asm_var == av) & (field_var == fv)]
        assembly_time = subgroup[subgroup['tag'] == main_tag]['time'].item()
        total = np.sum(subgroup['time']) - assembly_time
        reminder = assembly_time - total
        rm[key] = reminder #, reminder/total)
    rm_mean = np.mean(list(rm.values()))
    rm_std = np.std(list(rm.values()))
    print(f"{repr(name):<40}  reminder: {rm_mean:<10.5} sd: {300*rm_std/rm_mean:3.0f}%")
            
    
    # Patch creation
    add_row(group, tags == 'add_integrals_to_patch', 'colect_patch', 0.0)
    add_row(group, tags == 'create_patch', 'create_patch', 0.0)
    # Fields - Cache Update
    field_const_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'const')
    t_field_const = add_row(group, field_const_mask, 'field_const', 0.0)
    field_model_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'model')
    add_row(group, field_model_mask, 'field_model',  t_field_const)

    # Assembly integrals
    for it in integral.unique():
        if it == '':
            continue
        loop_mask = (asm_var == 'EvalFields') & (integral == it)
        t_loop = add_row(group, loop_mask, f'{it}_loop', 0.0)
        local_mask = (asm_var == 'ComputeLocal') & (integral == it)
        t_local = add_row(group, local_mask, f'{it}_local', t_loop)
        global_mask = (asm_var == 'FullAssembly') & (integral == it)
        add_row(group, global_mask, f'{it}_global', t_local)
    
    # Reminder - taking mean value, bute there could be huge deviances, but mostly for small values    
    assembly_mask = (asm_var == 'FullAssembly') & (tags == main_tag)
    mod_group = group[assembly_mask].copy()
    mod_group['time'] = rm_mean
    add_row(mod_group, mod_group['time'] == mod_group['time'], 'reminder', 0.0)
    
detail_df = pd.DataFrame(new_rows)
#table_overview(detail_df)
display(detail_df)
# Out:
# (0, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.082757   sd:   4%
# (0, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.082141   sd:   2%
# (0, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.12611    sd:  10%
# (0, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.00832    sd:  10%
# (0, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.0079458  sd:   2%
# (0, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.013859   sd:  29%
# (0, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.001186   sd:  54%
# (0, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.00084831 sd:   3%
# (0, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0028616  sd:  99%
# (0, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.082295   sd:   2%
# (0, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.081992   sd:   2%
# (0, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12568    sd:  10%
# (0, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.0084464  sd:   9%
# (0, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.008142   sd:   2%
# (0, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.013984   sd:  27%
# (0, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.0011245  sd:  45%
# (0, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.00084474 sd:   3%
# (0, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0028394  sd:  99%
# (0, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.085083   sd:   2%
# (0, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.085474   sd:   5%
# (0, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.13253    sd:   9%
# (0, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.0082491  sd:  11%
# (0, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0079082  sd:   3%
# (0, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013631   sd:  28%
# (0, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.0011329  sd:  59%
# (0, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00079293 sd:   6%
# (0, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0027843  sd: 103%
# (0, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.081754   sd:   2%
# (0, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.081028   sd:   2%
# (0, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.12475    sd:  10%
# (0, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.0085255  sd:   9%
# (0, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.0081508  sd:   2%
# (0, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.014191   sd:  29%
# (0, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.0011571  sd:  58%
# (0, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00080498 sd:   8%
# (0, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.002814   sd: 104%
# (0, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.087365   sd:   3%
# (0, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.088168   sd:   5%
# (0, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.18429    sd:  17%
# (0, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.0091505  sd:  11%
# (0, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.0087112  sd:   2%
# (0, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.019705   sd:  26%
# (0, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.0012164  sd:  48%
# (0, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.00091743 sd:   5%
# (0, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.003418   sd:  86%
# (0, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.090089   sd:   2%
# (0, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.089476   sd:   1%
# (0, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.17813    sd:  14%
# (0, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.0095027  sd:   8%
# (0, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.0090873  sd:   2%
# (0, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.019753   sd:  25%
# (0, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.0013205  sd:  44%
# (0, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.0010271  sd:   7%
# (0, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.00361    sd:  83%
# (0, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.089075   sd:   3%
# (0, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.088383   sd:   2%
# (0, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.18181    sd:  15%
# (0, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.0092287  sd:   9%
# (0, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.0088798  sd:   3%
# (0, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.019483   sd:  25%
# (0, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0012435  sd:  47%
# (0, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.00093333 sd:   4%
# (0, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0034599  sd:  85%
# (0, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.089643   sd:   2%
# (0, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.089503   sd:   3%
# (0, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.18036    sd:  16%
# (0, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.0097688  sd:   7%
# (0, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.0093132  sd:   2%
# (0, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.020306   sd:  25%
# (0, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.0011956  sd:  50%
# (0, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.00087734 sd:   7%
# (0, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0033398  sd:  89%
# (1, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.082592   sd:   2%
# (1, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.08277    sd:   2%
# (1, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.12676    sd:  11%
# (1, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.008329   sd:   9%
# (1, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.0079818  sd:   1%
# (1, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.01375    sd:  27%
# (1, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.0011177  sd:  46%
# (1, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.00082729 sd:   3%
# (1, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0028241  sd: 100%
# (1, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.082974   sd:   2%
# (1, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.082738   sd:   1%
# (1, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12766    sd:  12%
# (1, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.0085754  sd:  10%
# (1, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.0082239  sd:   2%
# (1, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.01415    sd:  28%
# (1, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.0011495  sd:  49%
# (1, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.00086431 sd:   5%
# (1, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.002876   sd:  99%
# (1, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.085862   sd:   2%
# (1, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.085647   sd:   2%
# (1, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.1323     sd:   8%
# (1, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.008288   sd:   8%
# (1, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0079783  sd:   1%
# (1, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013723   sd:  27%
# (1, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.0010578  sd:  49%
# (1, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00078194 sd:   3%
# (1, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.002756   sd: 103%
# (1, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.082106   sd:   2%
# (1, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.081763   sd:   1%
# (1, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.12562    sd:  10%
# (1, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.0085277  sd:   9%
# (1, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.0083298  sd:   8%
# (1, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.014032   sd:  27%
# (1, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.001084   sd:  51%
# (1, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00080424 sd:   6%
# (1, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0027717  sd: 103%
# (1, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.088473   sd:   1%
# (1, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.088264   sd:   2%
# (1, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.18229    sd:  17%
# (1, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.0092298  sd:  11%
# (1, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.0088383  sd:   1%
# (1, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.019736   sd:  28%
# (1, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.0012419  sd:  48%
# (1, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.00094268 sd:   5%
# (1, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0034669  sd:  86%
# (1, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.091391   sd:   6%
# (1, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.091343   sd:   3%
# (1, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.17887    sd:  14%
# (1, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.0095439  sd:   8%
# (1, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.0091923  sd:   2%
# (1, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.019942   sd:  26%
# (1, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.0013266  sd:  44%
# (1, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.001027   sd:   5%
# (1, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0036377  sd:  83%
# (1, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.089232   sd:   1%
# (1, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.088975   sd:   2%
# (1, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.18232    sd:  15%
# (1, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.0093289  sd:  10%
# (1, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.0090087  sd:   3%
# (1, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.019787   sd:  23%
# (1, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0012214  sd:  46%
# (1, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.00092659 sd:   4%
# (1, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0034121  sd:  86%
# (1, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.090423   sd:   3%
# (1, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.09001    sd:   2%
# (1, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.17914    sd:  16%
# (1, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.0097976  sd:  11%
# (1, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.0097461  sd:  22%
# (1, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.020119   sd:  26%
# (1, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.0011752  sd:  47%
# (1, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.00088057 sd:   3%
# (1, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0033297  sd:  89%
# (2, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.083818   sd:   5%
# (2, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.082653   sd:   2%
# (2, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.12651    sd:  11%
# (2, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.0083861  sd:  10%
# (2, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.0080465  sd:   3%
# (2, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.013796   sd:  27%
# (2, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.0011518  sd:  53%
# (2, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.0008342  sd:   7%
# (2, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0028308  sd: 101%
# (2, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.083528   sd:   3%
# (2, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.083104   sd:   2%
# (2, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12602    sd:  10%
# (2, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.0086086  sd:  10%
# (2, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.0082585  sd:   3%
# (2, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.014318   sd:  31%
# (2, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.0011748  sd:  51%
# (2, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.00086881 sd:   4%
# (2, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0028726  sd:  98%
# (2, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.086191   sd:   4%
# (2, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.085576   sd:   2%
# (2, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.13068    sd:   8%
# (2, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.0084362  sd:  10%
# (2, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0079881  sd:   4%
# (2, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013933   sd:  30%
# (2, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.0010735  sd:  51%
# (2, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00078559 sd:   7%
# (2, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0027662  sd: 103%
# (2, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.082929   sd:   4%
# (2, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.082574   sd:   6%
# (2, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.12452    sd:   9%
# (2, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.0086353  sd:  10%
# (2, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.0082436  sd:   4%
# (2, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.014126   sd:  27%
# (2, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.0010881  sd:  51%
# (2, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00080489 sd:   6%
# (2, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0028217  sd: 103%
# (2, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.088506   sd:   3%
# (2, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.088349   sd:   3%
# (2, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.18235    sd:  15%
# (2, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.0093859  sd:  13%
# (2, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.0088311  sd:   3%
# (2, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.019777   sd:  28%
# (2, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.0012296  sd:  47%
# (2, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.00093048 sd:   7%
# (2, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0034274  sd:  86%
# (2, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.09139    sd:   5%
# (2, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.091025   sd:   3%
# (2, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.1779     sd:  14%
# (2, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.009642   sd:  11%
# (2, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.0091998  sd:   3%
# (2, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.019929   sd:  27%
# (2, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.0013351  sd:  44%
# (2, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.0010287  sd:   6%
# (2, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0036292  sd:  82%
# (2, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.090044   sd:   3%
# (2, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.089197   sd:   2%
# (2, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.18506    sd:  19%
# (2, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.0093713  sd:   8%
# (2, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.008985   sd:   4%
# (2, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.019785   sd:  27%
# (2, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0012433  sd:  49%
# (2, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.00093299 sd:   8%
# (2, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0034209  sd:  86%
# (2, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.090953   sd:   3%
# (2, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.090182   sd:   3%
# (2, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.17951    sd:  14%
# (2, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.0097713  sd:  10%
# (2, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.0094314  sd:   4%
# (2, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.020384   sd:  26%
# (2, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.0012005  sd:  49%
# (2, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.00089124 sd:   7%
# (2, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0033467  sd:  88%
# (3, '2D', 'B_refined', 'L', 'Mass')       reminder: 0.082662   sd:   2%
# (3, '2D', 'B_refined', 'L', 'Sources')    reminder: 0.082397   sd:   2%
# (3, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.12636    sd:  10%
# (3, '2D', 'B_refined', 'M', 'Mass')       reminder: 0.0083577  sd:   9%
# (3, '2D', 'B_refined', 'M', 'Sources')    reminder: 0.0080071  sd:   2%
# (3, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.013775   sd:  29%
# (3, '2D', 'B_refined', 'S', 'Mass')       reminder: 0.0011046  sd:  48%
# (3, '2D', 'B_refined', 'S', 'Sources')    reminder: 0.00082413 sd:   3%
# (3, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0028012  sd: 100%
# (3, '2D', 'B_uniform', 'L', 'Mass')       reminder: 0.083875   sd:   5%
# (3, '2D', 'B_uniform', 'L', 'Sources')    reminder: 0.0829     sd:   2%
# (3, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12563    sd:   9%
# (3, '2D', 'B_uniform', 'M', 'Mass')       reminder: 0.0086086  sd:  10%
# (3, '2D', 'B_uniform', 'M', 'Sources')    reminder: 0.0082871  sd:   4%
# (3, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.014236   sd:  30%
# (3, '2D', 'B_uniform', 'S', 'Mass')       reminder: 0.0011539  sd:  48%
# (3, '2D', 'B_uniform', 'S', 'Sources')    reminder: 0.00086674 sd:   5%
# (3, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0028676  sd:  99%
# (3, '2D', 'L_refined', 'L', 'Mass')       reminder: 0.085842   sd:   2%
# (3, '2D', 'L_refined', 'L', 'Sources')    reminder: 0.08602    sd:   3%
# (3, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.13121    sd:   8%
# (3, '2D', 'L_refined', 'M', 'Mass')       reminder: 0.0082914  sd:   9%
# (3, '2D', 'L_refined', 'M', 'Sources')    reminder: 0.0080005  sd:   5%
# (3, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013778   sd:  28%
# (3, '2D', 'L_refined', 'S', 'Mass')       reminder: 0.0010635  sd:  49%
# (3, '2D', 'L_refined', 'S', 'Sources')    reminder: 0.00078403 sd:   3%
# (3, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0027421  sd: 102%
# (3, '2D', 'L_uniform', 'L', 'Mass')       reminder: 0.082554   sd:   2%
# (3, '2D', 'L_uniform', 'L', 'Sources')    reminder: 0.082175   sd:   3%
# (3, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.12577    sd:  11%
# (3, '2D', 'L_uniform', 'M', 'Mass')       reminder: 0.0085215  sd:   7%
# (3, '2D', 'L_uniform', 'M', 'Sources')    reminder: 0.0081999  sd:   3%
# (3, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.01404    sd:  29%
# (3, '2D', 'L_uniform', 'S', 'Mass')       reminder: 0.001071   sd:  49%
# (3, '2D', 'L_uniform', 'S', 'Sources')    reminder: 0.00079523 sd:   3%
# (3, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0027464  sd: 102%
# (3, '3D', 'B_refined', 'L', 'Mass')       reminder: 0.088384   sd:   0%
# (3, '3D', 'B_refined', 'L', 'Sources')    reminder: 0.087895   sd:   1%
# (3, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.18067    sd:  13%
# (3, '3D', 'B_refined', 'M', 'Mass')       reminder: 0.0093089  sd:  11%
# (3, '3D', 'B_refined', 'M', 'Sources')    reminder: 0.0087949  sd:   2%
# (3, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.019869   sd:  28%
# (3, '3D', 'B_refined', 'S', 'Mass')       reminder: 0.0012267  sd:  47%
# (3, '3D', 'B_refined', 'S', 'Sources')    reminder: 0.00092559 sd:   5%
# (3, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0034337  sd:  86%
# (3, '3D', 'B_uniform', 'L', 'Mass')       reminder: 0.09126    sd:   2%
# (3, '3D', 'B_uniform', 'L', 'Sources')    reminder: 0.090791   sd:   2%
# (3, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.17887    sd:  14%
# (3, '3D', 'B_uniform', 'M', 'Mass')       reminder: 0.0095516  sd:   8%
# (3, '3D', 'B_uniform', 'M', 'Sources')    reminder: 0.009214   sd:   3%
# (3, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.019916   sd:  27%
# (3, '3D', 'B_uniform', 'S', 'Mass')       reminder: 0.001328   sd:  45%
# (3, '3D', 'B_uniform', 'S', 'Sources')    reminder: 0.0010259  sd:   4%
# (3, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0036082  sd:  83%
# (3, '3D', 'L_refined', 'L', 'Mass')       reminder: 0.089753   sd:   3%
# (3, '3D', 'L_refined', 'L', 'Sources')    reminder: 0.089226   sd:   2%
# (3, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.18058    sd:  14%
# (3, '3D', 'L_refined', 'M', 'Mass')       reminder: 0.0092892  sd:  10%
# (3, '3D', 'L_refined', 'M', 'Sources')    reminder: 0.0089467  sd:   2%
# (3, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.019728   sd:  26%
# (3, '3D', 'L_refined', 'S', 'Mass')       reminder: 0.0012245  sd:  46%
# (3, '3D', 'L_refined', 'S', 'Sources')    reminder: 0.00093105 sd:   5%
# (3, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0034249  sd:  86%
# (3, '3D', 'L_uniform', 'L', 'Mass')       reminder: 0.090056   sd:   2%
# (3, '3D', 'L_uniform', 'L', 'Sources')    reminder: 0.0904     sd:   3%
# (3, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.17979    sd:   9%
# (3, '3D', 'L_uniform', 'M', 'Mass')       reminder: 0.009799   sd:   9%
# (3, '3D', 'L_uniform', 'M', 'Sources')    reminder: 0.0093653  sd:   3%
# (3, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.020158   sd:  26%
# (3, '3D', 'L_uniform', 'S', 'Mass')       reminder: 0.0011736  sd:  45%
# (3, '3D', 'L_uniform', 'S', 'Sources')    reminder: 0.00088102 sd:   5%
# (3, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0033226  sd:  87%
#       run_id size dim    n_el field_variant assembly_variant assembly_class  \
# 0          0    L  2D  304838         model     FullAssembly           Mass
# 1          0    L  2D  304838         model     ComputeLocal           Mass
# 2          0    L  2D  304838         const       EvalFields           Mass
# 3          0    L  2D  304838         model       EvalFields           Mass
# 4          0    L  2D  304838         model     FullAssembly           Mass
# ...      ...  ...  ..     ...           ...              ...            ...
# 7771       3    S  3D    2889         const       EvalFields      Stiffness
# 7772       3    S  3D    2889         model       EvalFields      Stiffness
# 7773       3    S  3D    2889         model     ComputeLocal      Stiffness
# 7774       3    S  3D    2889         model     FullAssembly      Stiffness
# 7775       3    S  3D    2889         model     FullAssembly      Stiffness
#
#                  tag  n_calls integral_type      time  time_fraction  \
# 0       colect_patch  1219352                0.204072       0.100476
# 1       colect_patch  1219352                0.203929       0.120557
# 2       colect_patch  1219352                0.218136       0.509071
# 3       colect_patch  1219352                0.205659       0.259688
# 4       create_patch    12320                0.096276       0.047402
# ...              ...      ...           ...       ...            ...
# 7771    dimjoin_loop      696       dimjoin  0.000035       0.001153
# 7772    dimjoin_loop      696       dimjoin  0.000037       0.000324
# 7773   dimjoin_local      696       dimjoin  0.000015       0.000173
# 7774  dimjoin_global      696       dimjoin  0.000002       0.000158
# 7775        reminder        4                0.003323       0.803835
#
#       time_fraction_of_reminder         parent_tag  level  mesh_type
# 0                           NaN       MassAssembly      9  B_refined
# 1                           NaN       MassAssembly      9  B_refined
# 2                           NaN       MassAssembly      9  B_refined
# 3                           NaN       MassAssembly      9  B_refined
# 4                           NaN       MassAssembly      9  B_refined
# ...                         ...                ...    ...        ...
# 7771                        NaN  StiffnessAssembly      9  L_uniform
# 7772                        NaN  StiffnessAssembly      9  L_uniform
# 7773                        NaN  StiffnessAssembly      9  L_uniform
# 7774                        NaN  StiffnessAssembly      9  L_uniform
# 7775                   0.011695           assembly      8  L_uniform
#
# [7776 rows x 16 columns]

# %%
ddf = detail_df.copy()
ddf['dim_size'] = ddf['dim'] + '_' + ddf['size']
ddf['time'] = ddf['time'] / ddf['n_el']
#ddf.set_index(['assembly_class'], inplace=True)
#print(ddf.columns)
#print(detail_df['assembly_class'])

# Define custom colors matching structure of `dim_size` values
cold_tones = ['#5F3EA0', '#6495ED', '#00CED1'] 
warm_tones = ['#a42d14', '#ff5308', '#f0f03a', ] 
custom_palette = cold_tones + warm_tones
sns.set_palette(custom_palette)

assembly_classes = ddf['assembly_class'].unique()
print(assembly_classes)

facet_grid = sns.catplot(data=ddf, x='time', y='tag', hue='dim_size', row='assembly_class',
            kind='strip', orient='h', sharex=False, aspect=2, jitter=0.25, size=3,
            row_order=assembly_classes,
            legend_out=False)

handles, labels = facet_grid.axes[2][0].get_legend_handles_labels()
#print(handles, labels)
for ax, loc in zip(facet_grid.axes.flatten(), [1,4,4]):
    ax.legend(handles, labels, loc=loc)
facet_grid.axes[2][0].set_xlabel("Time per element")
facet_grid.fig.subplots_adjust(top=0.93) # adjust the Figure in rp
facet_grid.fig.suptitle(f'Detailed view of: {flow123d_version}')

plt.savefig("detailed_plot.pdf")
# Out:
# ['Mass' 'Sources' 'Stiffness']

# %% [markdown]
# ## Interpretation
#
# ### Patch creation
# - patch creation overhead is relatively small, comparable to field_model evaluation for matrix assemblies
# - the overhead is much more significant for simple assembly like `Sources`
# - the overhead in field evaluation and field access is not included, so in fact, the overhead could be higher 1.5 times
#
# ### Field evaluation
# - It seems that evaluation of tensor-valued fields necessary in `Stiffness` is much more costly. Also, different kinds of fields are possibly in use.
# - Constant value fields have negligible evaluation time.
#
# ### Assembly
# - `<integral>_global` are calculated from noisy `<integral>_local` values, so it is noisy as well, leading to even negative values for fast vector-only assembly of `Sources`.
# - Nevertheless, it is relatively costly for `Stiffness` and clearly correlated to the number of calls since it is higher for 3d meshes.
# - Local evaluations are the highest in all three cases. Probably dominated by `FEValues.reinit` (according to VTUNE analysis).
