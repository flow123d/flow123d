# %% [markdown]
# # Extract dataframe
#
# In order to mimick dg_transport, benchmark use zero_time_step and 4 calls of update_solution.
# Therefore initially there were two items for every group. One with n_calls==1 (zero_time_step)
# and one with n_calls=4 (4 x update_solution). The loading script has been hacked to skip "ZERO-TIME STEP" tag
# However all tags excepting "full_mesh" are called in 4 assembly loops.

# %%
# zip archive or pattern
profiler_files="24_06_04_dg_asm.zip"
#profiler_files="../../../bin/benchmark/dg_asm-1-bench_profiler_*.json"

# %%
print(profiler_files)
# Out:
# 24_06_04_dg_asm.zip

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
import dg_asm_bench_postprocess as bp

# load and process Profiler JSON output
df_orig = df = bp.load_profiler_data(profiler_files)

from IPython.display import Markdown, display
    
def table_overview(df):
    for col in df.columns:
        unique = df[col].unique()
        is_factor =  all([type(v) is str for v in unique])
        value_set = np.sort(unique)
        np.set_printoptions(threshold=30)
        value_set = np.array2string(value_set, precision=2, separator=',')
        display(Markdown(f'**{col}**: {value_set}'))
                

table_overview(df_orig)
# Out:
# Input profiler files:  [Path('24_06_04_dg_asm.zip', 'dg_asm-1-bench_profiler_1.json'), Path('24_06_04_dg_asm.zip', 'dg_asm-1-bench_profiler_2.json'), Path('24_06_04_dg_asm.zip', 'dg_asm-1-bench_profiler_3.json'), Path('24_06_04_dg_asm.zip', 'dg_asm-1-bench_profiler_4.json')]
# **branch**: ['DF_patch_fe_data_tables']
# **commit**: ['b678bc1']
# **run_id**: [0,1,2,3]
# **domain_shape**: ['B','L']
# **mesh_size**: ['L','M','S']
# **spacedim**: ['2D','3D']
# **uniformity**: ['refined','uniform']
# **n_mesh_elements**: [  2770.,  2806.,  2889.,  2918.,  3041.,  3046.,  3049.,  3392., 29250.,
#   29346., 30046., 30168., 30186., 30574., 31423., 31914.,301689.,302320.,
#  304838.,305121.,305984.,308574.,310479.,316110.]
# **n_repeats**: [ 1,10]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Mass','Sources','Stiffness']
# **tag**: ['MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'add_integrals_to_patch','assemble_fluxes_boundary',
#  'assemble_fluxes_elem_elem','assemble_fluxes_elem_side',
#  'assemble_volume_integrals','cache_update','create_patch','full_mesh',
#  'patch_reinit']
# **number_of_calls**: [      1,      4,     10,...,1298992,1301748,1309856]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [5.44e-05,5.52e-05,5.54e-05,...,7.19e+01,7.20e+01,7.24e+01]
# **time_fraction**: [9.41e-05,9.70e-05,9.83e-05,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0. ,0. ,0. ,...,0.1,0.1,nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'assembly']
# **level**: [5,8,9]

# %% [markdown]
# # Basic dataset modifications
# - rename some columns
# - extract `branch` and `commit` columns into `flow123d_version` variable, drop these columns
# - fix `n_el` type
# - merge `shape` and `uniformity` columns
# - Divide 'time' and 'number_of_calls' by 'n_repeats'

# %%
# Get benchmarked sources version.
df = df_orig.copy()
assert df['branch'].nunique() == 1
assert df['commit'].nunique() == 1
flow123d_version = f"{df['branch'].loc[0]}_{df['commit'].loc[0]}"
print("Benchmarked Flow123d version: ", flow123d_version)
df.drop(columns=["branch", "commit"], inplace=True)

# rename some columns:
col_map = dict(spacedim='dim', mesh_size='size', domain_shape='shape', n_mesh_elements='n_el', 
               number_of_calls='n_calls')
df.rename(columns=col_map, inplace=True)

# int values for 'n_el', 'n_calls' columns
df['n_el'] = df['n_el'].astype(int)

# merge mesh shape and uniformity
df['mesh_type'] = [f"{row['shape']}_{row['uniformity']}" for index, row in df.iterrows()]
df.drop(columns=["shape", "uniformity"], inplace=True)

def apply_n_repeats(df):
    repeated_cols = ['n_calls', 'time']
    for c in repeated_cols:
        df[c] /= df['n_repeats']
    df['n_calls'] = df['n_calls'].astype(int)
    df.drop(columns=['n_repeats'], inplace=True)
    return df

df = apply_n_repeats(df)


table_overview(df)
# Out:
# Benchmarked Flow123d version:  DF_patch_fe_data_tables_b678bc1
# **run_id**: [0,1,2,3]
# **size**: ['L','M','S']
# **dim**: ['2D','3D']
# **n_el**: [  2770,  2806,  2889,  2918,  3041,  3046,  3049,  3392, 29250, 29346,
#   30046, 30168, 30186, 30574, 31423, 31914,301689,302320,304838,305121,
#  305984,308574,310479,316110]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Mass','Sources','Stiffness']
# **tag**: ['MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'add_integrals_to_patch','assemble_fluxes_boundary',
#  'assemble_fluxes_elem_elem','assemble_fluxes_elem_side',
#  'assemble_volume_integrals','cache_update','create_patch','full_mesh',
#  'patch_reinit']
# **n_calls**: [      1,      4,    112,...,1298992,1301748,1309856]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [5.54e-06,5.55e-06,5.55e-06,...,7.19e+01,7.20e+01,7.24e+01]
# **time_fraction**: [9.41e-05,9.70e-05,9.83e-05,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0. ,0. ,0. ,...,0.1,0.1,nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MassAssembly','SourcesAssembly','StiffnessAssembly',
#  'assembly']
# **level**: [5,8,9]
# **mesh_type**: ['B_refined','B_uniform','L_refined','L_uniform']

# %% [markdown]
# # Mesh times comparison
# - plot `full_mesh` time for mesh and run ID variants.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def mesh_cases_plot(df, time_label):
    cases_cols = ['dim_size', 'mesh_type', 'run_id', 'variant']
    stacked_df = df.groupby(cases_cols)['time'].sum().unstack('variant').fillna(0)
    n_rows = len(stacked_df)
    
    # for grouping by position on Y axis
    level_labels = [l for l in stacked_df.index.levels]
    level_vals = [pd.Categorical(l).codes for l in stacked_df.index.levels]
    int_df = stacked_df.copy()
    int_df.index = stacked_df.index.set_levels(level_vals, level=[0, 1, 2])

    bar_width = 0.5
    steps = []
    ticks = []
    tick_labels = []
    last_idx = (0,-1,-1)
    step = np.array([0.5, 0.5, bar_width])
    for idx in int_df.index.drop_duplicates():
        diff = np.array(idx) - np.array(last_idx)
        last_idx = idx
        if diff[1] != 0:
            ticks.append(len(steps))
            tick_labels.append(f'{level_labels[0][idx[0]]}, {level_labels[1][idx[1]]: >12}')
        steps.append(np.sum(step[diff != 0]))
        
    positions = np.cumsum(steps)
    ticks = positions[ticks]        
    
    # Initialize a color palette
    palette = sns.color_palette("tab10", len(stacked_df.columns))
    
    # Plotting
    fig, ax = plt.subplots(figsize=(10, 6))
  
    # Create stacked bars
    bottom = np.zeros(n_rows)
    for j, col in enumerate(stacked_df.columns):
            ax.barh(positions, stacked_df[col], bar_width, left=bottom, color=palette[j], label=col)
            bottom += stacked_df[col]
    
    ax.set_yticks(ticks)
    ax.set_yticklabels(tick_labels)
    ax.legend(title='Assembly Variants')
    ax.set_xlabel(time_label)
    ax.set_ylabel('Mesh variants: dim_size, shape_refine')
    ax.set_title(f'Overview of benchmark: {flow123d_version}')
    
    # Display
    fig.tight_layout()
    plt.show()
    return fig
    

df_sumrun = df[df['tag'] == 'full_mesh'].copy()
df_sumrun['dim_size'] = df_sumrun['dim'] + '_' + df_sumrun['size']
def variant(row):
    var = row['assembly_variant']
    if var == 'EvalFields':
        var = f"Fields_{row['field_variant']}"
    return var

df_sumrun['variant'] = df.apply(variant, axis=1)
fig = mesh_cases_plot(df_sumrun, 'Time [s]')

# %% [markdown]
# ## Relative Mesh comparison
# Comparison of time per element allows us to see:
#
# - nearly no difference between mesh sizes, i.e., almost zero assembly overhead or
#   additional 'fit to the cache' advantages of small meshes.
#   Fitting all to the cache probably could not happen as individual data are allocated at different places.
#   It seems more probable that even for small meshes (S ~ 1000 elements)
#   the calculation has some cache misses. Needs better investigation.
#
# - significant impact of 3D calculation. 3D has about 4/3 times more DOFs, the increase is slightly higher,
#   possibly due to a larger increase in the number of quadrature points o
#
# - very small impact of `mesh_type`
#
# - the significant impact of `run_id` we should rather increase the number of runs to 5. Memory layout could
#   have some impact. Ideally, we should minimize this impact by own arena allocator used for
#   assembly structures on the patch.

# %%
df_reltime = df_sumrun.copy()
df_reltime['time'] = df_reltime['time'] / df_reltime['n_el'] * 1000
fig = mesh_cases_plot(df_reltime, 'Time per 1000 element [s]')
fig.savefig("overview_plot.pdf")

# %% [markdown]
# # Aggregate runs
# - compute suitable position and variance indicators
# - report (tags) with high variability and high time fraction
#
# Se that there is much higher `run_ID` variability at a detailed level and even for long time frames.

# %%
index_cols = ['dim', 'mesh_type', 'size', 'assembly_variant', 'field_variant', 'assembly_class', 'integral_type', 'tag']
grouped = df.groupby(index_cols)
#print(grouped.size())
n_runs = len(df['run_id'].unique())
assert all(grouped.size() == n_runs)
# Available groups
# print(grouped.groups.keys())
# Rows in a single group:
# display(grouped.get_group(('2D', 'B_refined', 'L', 'ComputeLocal', 'model', 'Mass', '', 'MassAssembly')))

def get_median_row(group):
    min_t = group['time'].min()
    median_t = group['time'].median()
    max_t = group['time'].max()
    row = group[group['time'] == min_t]
    row['Err'] = (median_t - min_t) / min_t
    return row

# Apply the custom function to each group
df_med = grouped.apply(get_median_row).reset_index(drop=True)
#display(result)
df_med.drop(columns=['run_id'], inplace=True)
df_med.drop(columns=['n_calls', 'integral_type', 'n_el', 'time_fraction_of_reminder', 'parent_tag', 'level'], inplace=True)

# Sort the DataFrame by column 'A'
# There are many items with big error and big time fraction.
sorted_df = df_med.sort_values(by='Err', ascending=False)
big_err = sorted_df[sorted_df['Err'] > 0.1]
big_err_and_fraction = big_err[big_err['time_fraction'] > 0.05]
# Display the sorted DataFrame
display(big_err_and_fraction.head(30))


# Result kee run_id and try to plot all three values in plots.
# Out:
# /tmp/ipykernel_312799/277180933.py:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_med = grouped.apply(get_median_row).reset_index(drop=True)
# Empty DataFrame
# Columns: [size, dim, field_variant, assembly_variant, assembly_class, tag, time, time_fraction, mesh_type, Err]
# Index: []

# %% [markdown]
# # Detailed view
#
# 1. reduce assembly variants to new tags having complete decomposition of a single assembly
# 2. separate plot for each `assembly_class`
# 3. group by:
#    `dim_size`, `tag`
# 4. in every group points from: reduction, runs, mesh_type `

# %%
# reduce columns: assembly_variant, field_variant, integral_type
# to tags: 
# field_const, field_model
# <integral>_loop, <integral>_local, <integral>_global
# reminder (of assembly)

new_rows = {}

def add_row(group, orig_row_mask, tag, time_subtrack):
    """
    Add new row to the dataset by taking `orig_row_mask` from `group`
    setting the `tag` and subtrack `time_subtrack` from the `time` column.
    We return original `time` value.
    """
    orig = group[orig_row_mask].to_dict('list')
    orig_time = np.mean(orig['time'])
    for i in range(len(orig['time'])):
        #print(new_row)
        orig['time'][i] -= time_subtrack
        orig['tag'][i] = tag
    for key, item_dict in orig.items():
        col = new_rows.setdefault(key, [])
        col.extend(item_dict)
    return orig_time
    

# check same time of some tags between variants
index_cols = ['run_id', 'dim', 'mesh_type', 'size',  'assembly_class']
grouped = df.groupby(index_cols)

# Add column with assembly total times
#
for name, group in grouped:
    # skip full_mesh group
    if name[-1] == '':
        assert all(group['tag'] == 'full_mesh')
        continue
    main_tag = f"{name[-1]}Assembly"
    asm_var = group['assembly_variant']    
    field_var = group['field_variant']
    tags = group['tag']
    integral = group['integral_type']

    # compute reminders
    reminders = {
        'field_const':('EvalFields', 'const'),
        'field_model':('EvalFields', 'model'),
        'local': ('ComputeLocal', 'model'),
        'global': ('FullAssembly', 'model'),}
    rm = {}
    for key, (av, fv) in reminders.items():
        subgroup = group[(asm_var == av) & (field_var == fv)]
        assembly_time = subgroup[subgroup['tag'] == main_tag]['time'].item()
        total = np.sum(subgroup['time']) - assembly_time
        reminder = assembly_time - total
        rm[key] = reminder #, reminder/total)
    rm_mean = np.mean(list(rm.values()))
    rm_std = np.std(list(rm.values()))
    print(f"{repr(name):<40}  reminder: {rm_mean:<10.5} sd: {300*rm_std/rm_mean:3.0f}%")
            
    
    # Patch creation
    add_row(group, tags == 'add_integrals_to_patch', 'colect_patch', 0.0)
    add_row(group, tags == 'create_patch', 'create_patch', 0.0)
    # Fields - Cache Update
    field_const_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'const')
    t_field_const = add_row(group, field_const_mask, 'field_const', 0.0)
    field_model_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'model')
    add_row(group, field_model_mask, 'field_model',  t_field_const)

    # Assembly integrals
    for it in integral.unique():
        if it == '':
            continue
        loop_mask = (asm_var == 'EvalFields') & (integral == it)
        t_loop = add_row(group, loop_mask, f'{it}_loop', 0.0)
        local_mask = (asm_var == 'ComputeLocal') & (integral == it)
        t_local = add_row(group, local_mask, f'{it}_local', t_loop)
        global_mask = (asm_var == 'FullAssembly') & (integral == it)
        add_row(group, global_mask, f'{it}_global', t_local)
    
    # Reminder - taking mean value, bute there could be huge deviances, but mostly for small values    
    assembly_mask = (asm_var == 'FullAssembly') & (tags == main_tag)
    mod_group = group[assembly_mask].copy()
    mod_group['time'] = rm_mean
    add_row(mod_group, mod_group['time'] == mod_group['time'], 'reminder', 0.0)
    
detail_df = pd.DataFrame(new_rows)
#table_overview(detail_df)
display(detail_df)
# Out:
# (np.int64(0), '2D', 'B_refined', 'L', 'Mass')  reminder: 0.085029   sd:   2%
# (np.int64(0), '2D', 'B_refined', 'L', 'Sources')  reminder: 0.084857   sd:   2%
# (np.int64(0), '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.13535    sd:   3%
# (np.int64(0), '2D', 'B_refined', 'M', 'Mass')  reminder: 0.0085655  sd:   9%
# (np.int64(0), '2D', 'B_refined', 'M', 'Sources')  reminder: 0.0081956  sd:   1%
# (np.int64(0), '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.01462    sd:  22%
# (np.int64(0), '2D', 'B_refined', 'S', 'Mass')  reminder: 0.0011817  sd:  52%
# (np.int64(0), '2D', 'B_refined', 'S', 'Sources')  reminder: 0.00086015 sd:   6%
# (np.int64(0), '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0029459  sd:  96%
# (np.int64(0), '2D', 'B_uniform', 'L', 'Mass')  reminder: 0.085615   sd:   2%
# (np.int64(0), '2D', 'B_uniform', 'L', 'Sources')  reminder: 0.084908   sd:   1%
# (np.int64(0), '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.1357     sd:   5%
# (np.int64(0), '2D', 'B_uniform', 'M', 'Mass')  reminder: 0.0087987  sd:   8%
# (np.int64(0), '2D', 'B_uniform', 'M', 'Sources')  reminder: 0.0084523  sd:   2%
# (np.int64(0), '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.014859   sd:  22%
# (np.int64(0), '2D', 'B_uniform', 'S', 'Mass')  reminder: 0.0012048  sd:  50%
# (np.int64(0), '2D', 'B_uniform', 'S', 'Sources')  reminder: 0.00088891 sd:   4%
# (np.int64(0), '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0029614  sd:  94%
# (np.int64(0), '2D', 'L_refined', 'L', 'Mass')  reminder: 0.088973   sd:   4%
# (np.int64(0), '2D', 'L_refined', 'L', 'Sources')  reminder: 0.087761   sd:   2%
# (np.int64(0), '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.14146    sd:   6%
# (np.int64(0), '2D', 'L_refined', 'M', 'Mass')  reminder: 0.0085433  sd:   9%
# (np.int64(0), '2D', 'L_refined', 'M', 'Sources')  reminder: 0.0081355  sd:   1%
# (np.int64(0), '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.014506   sd:  22%
# (np.int64(0), '2D', 'L_refined', 'S', 'Mass')  reminder: 0.0011128  sd:  50%
# (np.int64(0), '2D', 'L_refined', 'S', 'Sources')  reminder: 0.00081312 sd:   2%
# (np.int64(0), '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0028223  sd:  97%
# (np.int64(0), '2D', 'L_uniform', 'L', 'Mass')  reminder: 0.084456   sd:   3%
# (np.int64(0), '2D', 'L_uniform', 'L', 'Sources')  reminder: 0.083946   sd:   1%
# (np.int64(0), '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.13347    sd:   3%
# (np.int64(0), '2D', 'L_uniform', 'M', 'Mass')  reminder: 0.0088323  sd:  11%
# (np.int64(0), '2D', 'L_uniform', 'M', 'Sources')  reminder: 0.0084799  sd:   1%
# (np.int64(0), '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.014854   sd:  22%
# (np.int64(0), '2D', 'L_uniform', 'S', 'Mass')  reminder: 0.0011337  sd:  52%
# (np.int64(0), '2D', 'L_uniform', 'S', 'Sources')  reminder: 0.00082603 sd:   4%
# (np.int64(0), '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0028456  sd:  96%
# (np.int64(0), '3D', 'B_refined', 'L', 'Mass')  reminder: 0.090843   sd:   3%
# (np.int64(0), '3D', 'B_refined', 'L', 'Sources')  reminder: 0.090333   sd:   2%
# (np.int64(0), '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.20006    sd:   5%
# (np.int64(0), '3D', 'B_refined', 'M', 'Mass')  reminder: 0.0095553  sd:  11%
# (np.int64(0), '3D', 'B_refined', 'M', 'Sources')  reminder: 0.0091538  sd:   5%
# (np.int64(0), '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.021774   sd:  17%
# (np.int64(0), '3D', 'B_refined', 'S', 'Mass')  reminder: 0.0012889  sd:  49%
# (np.int64(0), '3D', 'B_refined', 'S', 'Sources')  reminder: 0.00096262 sd:   4%
# (np.int64(0), '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0036209  sd:  78%
# (np.int64(0), '3D', 'B_uniform', 'L', 'Mass')  reminder: 0.09442    sd:   5%
# (np.int64(0), '3D', 'B_uniform', 'L', 'Sources')  reminder: 0.093503   sd:   2%
# (np.int64(0), '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.19592    sd:   5%
# (np.int64(0), '3D', 'B_uniform', 'M', 'Mass')  reminder: 0.0099535  sd:   8%
# (np.int64(0), '3D', 'B_uniform', 'M', 'Sources')  reminder: 0.0094805  sd:   1%
# (np.int64(0), '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.021644   sd:  18%
# (np.int64(0), '3D', 'B_uniform', 'S', 'Mass')  reminder: 0.001435   sd:  49%
# (np.int64(0), '3D', 'B_uniform', 'S', 'Sources')  reminder: 0.0010793  sd:   3%
# (np.int64(0), '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0039014  sd:  76%
# (np.int64(0), '3D', 'L_refined', 'L', 'Mass')  reminder: 0.092708   sd:   7%
# (np.int64(0), '3D', 'L_refined', 'L', 'Sources')  reminder: 0.095579   sd:  20%
# (np.int64(0), '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.19978    sd:   6%
# (np.int64(0), '3D', 'L_refined', 'M', 'Mass')  reminder: 0.0096476  sd:  10%
# (np.int64(0), '3D', 'L_refined', 'M', 'Sources')  reminder: 0.0092717  sd:   2%
# (np.int64(0), '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.021676   sd:  17%
# (np.int64(0), '3D', 'L_refined', 'S', 'Mass')  reminder: 0.0013193  sd:  51%
# (np.int64(0), '3D', 'L_refined', 'S', 'Sources')  reminder: 0.00096901 sd:   4%
# (np.int64(0), '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.003645   sd:  79%
# (np.int64(0), '3D', 'L_uniform', 'L', 'Mass')  reminder: 0.093031   sd:   3%
# (np.int64(0), '3D', 'L_uniform', 'L', 'Sources')  reminder: 0.092289   sd:   2%
# (np.int64(0), '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.19514    sd:   6%
# (np.int64(0), '3D', 'L_uniform', 'M', 'Mass')  reminder: 0.010111   sd:  11%
# (np.int64(0), '3D', 'L_uniform', 'M', 'Sources')  reminder: 0.009654   sd:   6%
# (np.int64(0), '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.02208    sd:  19%
# (np.int64(0), '3D', 'L_uniform', 'S', 'Mass')  reminder: 0.0012539  sd:  49%
# (np.int64(0), '3D', 'L_uniform', 'S', 'Sources')  reminder: 0.00092    sd:   3%
# (np.int64(0), '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0035219  sd:  79%
# (np.int64(1), '2D', 'B_refined', 'L', 'Mass')  reminder: 0.085359   sd:   3%
# (np.int64(1), '2D', 'B_refined', 'L', 'Sources')  reminder: 0.084907   sd:   2%
# (np.int64(1), '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.13529    sd:   4%
# (np.int64(1), '2D', 'B_refined', 'M', 'Mass')  reminder: 0.0086119  sd:  11%
# (np.int64(1), '2D', 'B_refined', 'M', 'Sources')  reminder: 0.008292   sd:   5%
# (np.int64(1), '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.014685   sd:  23%
# (np.int64(1), '2D', 'B_refined', 'S', 'Mass')  reminder: 0.0012065  sd:  54%
# (np.int64(1), '2D', 'B_refined', 'S', 'Sources')  reminder: 0.00087427 sd:   2%
# (np.int64(1), '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0029464  sd:  96%
# (np.int64(1), '2D', 'B_uniform', 'L', 'Mass')  reminder: 0.085807   sd:   3%
# (np.int64(1), '2D', 'B_uniform', 'L', 'Sources')  reminder: 0.085129   sd:   1%
# (np.int64(1), '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.1356     sd:   5%
# (np.int64(1), '2D', 'B_uniform', 'M', 'Mass')  reminder: 0.0088859  sd:  11%
# (np.int64(1), '2D', 'B_uniform', 'M', 'Sources')  reminder: 0.0085007  sd:   2%
# (np.int64(1), '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.014938   sd:  24%
# (np.int64(1), '2D', 'B_uniform', 'S', 'Mass')  reminder: 0.0012352  sd:  53%
# (np.int64(1), '2D', 'B_uniform', 'S', 'Sources')  reminder: 0.00090245 sd:   5%
# (np.int64(1), '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0029818  sd:  94%
# (np.int64(1), '2D', 'L_refined', 'L', 'Mass')  reminder: 0.088542   sd:   3%
# (np.int64(1), '2D', 'L_refined', 'L', 'Sources')  reminder: 0.087933   sd:   1%
# (np.int64(1), '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.14045    sd:   5%
# (np.int64(1), '2D', 'L_refined', 'M', 'Mass')  reminder: 0.008599   sd:  10%
# (np.int64(1), '2D', 'L_refined', 'M', 'Sources')  reminder: 0.0081886  sd:   1%
# (np.int64(1), '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.014613   sd:  22%
# (np.int64(1), '2D', 'L_refined', 'S', 'Mass')  reminder: 0.0011246  sd:  51%
# (np.int64(1), '2D', 'L_refined', 'S', 'Sources')  reminder: 0.00081991 sd:   3%
# (np.int64(1), '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0028331  sd:  94%
# (np.int64(1), '2D', 'L_uniform', 'L', 'Mass')  reminder: 0.084679   sd:   3%
# (np.int64(1), '2D', 'L_uniform', 'L', 'Sources')  reminder: 0.084403   sd:   2%
# (np.int64(1), '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.13453    sd:   5%
# (np.int64(1), '2D', 'L_uniform', 'M', 'Mass')  reminder: 0.0088597  sd:   9%
# (np.int64(1), '2D', 'L_uniform', 'M', 'Sources')  reminder: 0.0085974  sd:   5%
# (np.int64(1), '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.015086   sd:  24%
# (np.int64(1), '2D', 'L_uniform', 'S', 'Mass')  reminder: 0.0011377  sd:  54%
# (np.int64(1), '2D', 'L_uniform', 'S', 'Sources')  reminder: 0.00082307 sd:   5%
# (np.int64(1), '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0028377  sd:  97%
# (np.int64(1), '3D', 'B_refined', 'L', 'Mass')  reminder: 0.091299   sd:   4%
# (np.int64(1), '3D', 'B_refined', 'L', 'Sources')  reminder: 0.090385   sd:   1%
# (np.int64(1), '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.19975    sd:   8%
# (np.int64(1), '3D', 'B_refined', 'M', 'Mass')  reminder: 0.0094436  sd:   9%
# (np.int64(1), '3D', 'B_refined', 'M', 'Sources')  reminder: 0.0090104  sd:   1%
# (np.int64(1), '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.021585   sd:  16%
# (np.int64(1), '3D', 'B_refined', 'S', 'Mass')  reminder: 0.0012991  sd:  52%
# (np.int64(1), '3D', 'B_refined', 'S', 'Sources')  reminder: 0.00096041 sd:   4%
# (np.int64(1), '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0036372  sd:  79%
# (np.int64(1), '3D', 'B_uniform', 'L', 'Mass')  reminder: 0.093883   sd:   4%
# (np.int64(1), '3D', 'B_uniform', 'L', 'Sources')  reminder: 0.094622   sd:   3%
# (np.int64(1), '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.19409    sd:   6%
# (np.int64(1), '3D', 'B_uniform', 'M', 'Mass')  reminder: 0.0099434  sd:  10%
# (np.int64(1), '3D', 'B_uniform', 'M', 'Sources')  reminder: 0.0095029  sd:   2%
# (np.int64(1), '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.021481   sd:  17%
# (np.int64(1), '3D', 'B_uniform', 'S', 'Mass')  reminder: 0.0014266  sd:  49%
# (np.int64(1), '3D', 'B_uniform', 'S', 'Sources')  reminder: 0.001079   sd:   5%
# (np.int64(1), '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.003846   sd:  75%
# (np.int64(1), '3D', 'L_refined', 'L', 'Mass')  reminder: 0.092974   sd:   8%
# (np.int64(1), '3D', 'L_refined', 'L', 'Sources')  reminder: 0.092799   sd:   5%
# (np.int64(1), '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.19954    sd:   7%
# (np.int64(1), '3D', 'L_refined', 'M', 'Mass')  reminder: 0.0097007  sd:  13%
# (np.int64(1), '3D', 'L_refined', 'M', 'Sources')  reminder: 0.0092264  sd:   2%
# (np.int64(1), '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.021428   sd:  19%
# (np.int64(1), '3D', 'L_refined', 'S', 'Mass')  reminder: 0.0013     sd:  51%
# (np.int64(1), '3D', 'L_refined', 'S', 'Sources')  reminder: 0.00096458 sd:   6%
# (np.int64(1), '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0035914  sd:  79%
# (np.int64(1), '3D', 'L_uniform', 'L', 'Mass')  reminder: 0.093337   sd:   3%
# (np.int64(1), '3D', 'L_uniform', 'L', 'Sources')  reminder: 0.092665   sd:   1%
# (np.int64(1), '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.19254    sd:   6%
# (np.int64(1), '3D', 'L_uniform', 'M', 'Mass')  reminder: 0.010012   sd:  10%
# (np.int64(1), '3D', 'L_uniform', 'M', 'Sources')  reminder: 0.0096296  sd:   1%
# (np.int64(1), '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.021949   sd:  18%
# (np.int64(1), '3D', 'L_uniform', 'S', 'Mass')  reminder: 0.0012394  sd:  51%
# (np.int64(1), '3D', 'L_uniform', 'S', 'Sources')  reminder: 0.00091725 sd:   5%
# (np.int64(1), '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0034781  sd:  81%
# (np.int64(2), '2D', 'B_refined', 'L', 'Mass')  reminder: 0.084876   sd:   3%
# (np.int64(2), '2D', 'B_refined', 'L', 'Sources')  reminder: 0.084207   sd:   2%
# (np.int64(2), '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.13465    sd:   3%
# (np.int64(2), '2D', 'B_refined', 'M', 'Mass')  reminder: 0.0085734  sd:   9%
# (np.int64(2), '2D', 'B_refined', 'M', 'Sources')  reminder: 0.0082242  sd:   2%
# (np.int64(2), '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.014671   sd:  22%
# (np.int64(2), '2D', 'B_refined', 'S', 'Mass')  reminder: 0.0011608  sd:  51%
# (np.int64(2), '2D', 'B_refined', 'S', 'Sources')  reminder: 0.00085056 sd:   4%
# (np.int64(2), '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0029254  sd:  95%
# (np.int64(2), '2D', 'B_uniform', 'L', 'Mass')  reminder: 0.08543    sd:   2%
# (np.int64(2), '2D', 'B_uniform', 'L', 'Sources')  reminder: 0.084762   sd:   2%
# (np.int64(2), '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.13518    sd:   5%
# (np.int64(2), '2D', 'B_uniform', 'M', 'Mass')  reminder: 0.0088148  sd:   9%
# (np.int64(2), '2D', 'B_uniform', 'M', 'Sources')  reminder: 0.0084446  sd:   3%
# (np.int64(2), '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.014923   sd:  22%
# (np.int64(2), '2D', 'B_uniform', 'S', 'Mass')  reminder: 0.001197   sd:  49%
# (np.int64(2), '2D', 'B_uniform', 'S', 'Sources')  reminder: 0.00088199 sd:   4%
# (np.int64(2), '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0029868  sd:  95%
# (np.int64(2), '2D', 'L_refined', 'L', 'Mass')  reminder: 0.0887     sd:   3%
# (np.int64(2), '2D', 'L_refined', 'L', 'Sources')  reminder: 0.087872   sd:   4%
# (np.int64(2), '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.13982    sd:   4%
# (np.int64(2), '2D', 'L_refined', 'M', 'Mass')  reminder: 0.0085902  sd:  12%
# (np.int64(2), '2D', 'L_refined', 'M', 'Sources')  reminder: 0.0082031  sd:   2%
# (np.int64(2), '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.014655   sd:  23%
# (np.int64(2), '2D', 'L_refined', 'S', 'Mass')  reminder: 0.0011266  sd:  53%
# (np.int64(2), '2D', 'L_refined', 'S', 'Sources')  reminder: 0.00081341 sd:   5%
# (np.int64(2), '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0028769  sd:  98%
# (np.int64(2), '2D', 'L_uniform', 'L', 'Mass')  reminder: 0.084207   sd:   2%
# (np.int64(2), '2D', 'L_uniform', 'L', 'Sources')  reminder: 0.083777   sd:   1%
# (np.int64(2), '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.13279    sd:   3%
# (np.int64(2), '2D', 'L_uniform', 'M', 'Mass')  reminder: 0.008784   sd:  10%
# (np.int64(2), '2D', 'L_uniform', 'M', 'Sources')  reminder: 0.0084805  sd:   2%
# (np.int64(2), '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.014949   sd:  21%
# (np.int64(2), '2D', 'L_uniform', 'S', 'Mass')  reminder: 0.0011445  sd:  50%
# (np.int64(2), '2D', 'L_uniform', 'S', 'Sources')  reminder: 0.00082792 sd:   3%
# (np.int64(2), '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0028797  sd:  94%
# (np.int64(2), '3D', 'B_refined', 'L', 'Mass')  reminder: 0.091368   sd:   3%
# (np.int64(2), '3D', 'B_refined', 'L', 'Sources')  reminder: 0.09018    sd:   1%
# (np.int64(2), '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.20004    sd:   7%
# (np.int64(2), '3D', 'B_refined', 'M', 'Mass')  reminder: 0.0093933  sd:  10%
# (np.int64(2), '3D', 'B_refined', 'M', 'Sources')  reminder: 0.0090511  sd:   1%
# (np.int64(2), '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.02155    sd:  19%
# (np.int64(2), '3D', 'B_refined', 'S', 'Mass')  reminder: 0.0013133  sd:  51%
# (np.int64(2), '3D', 'B_refined', 'S', 'Sources')  reminder: 0.00097726 sd:   6%
# (np.int64(2), '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0036845  sd:  80%
# (np.int64(2), '3D', 'B_uniform', 'L', 'Mass')  reminder: 0.09388    sd:   2%
# (np.int64(2), '3D', 'B_uniform', 'L', 'Sources')  reminder: 0.09325    sd:   1%
# (np.int64(2), '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.19681    sd:   2%
# (np.int64(2), '3D', 'B_uniform', 'M', 'Mass')  reminder: 0.0098578  sd:   9%
# (np.int64(2), '3D', 'B_uniform', 'M', 'Sources')  reminder: 0.0093834  sd:   2%
# (np.int64(2), '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.021325   sd:  17%
# (np.int64(2), '3D', 'B_uniform', 'S', 'Mass')  reminder: 0.0013992  sd:  45%
# (np.int64(2), '3D', 'B_uniform', 'S', 'Sources')  reminder: 0.0010674  sd:   3%
# (np.int64(2), '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0038547  sd:  72%
# (np.int64(2), '3D', 'L_refined', 'L', 'Mass')  reminder: 0.092107   sd:   3%
# (np.int64(2), '3D', 'L_refined', 'L', 'Sources')  reminder: 0.09138    sd:   1%
# (np.int64(2), '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.1987     sd:   5%
# (np.int64(2), '3D', 'L_refined', 'M', 'Mass')  reminder: 0.0097358  sd:  13%
# (np.int64(2), '3D', 'L_refined', 'M', 'Sources')  reminder: 0.0092289  sd:   1%
# (np.int64(2), '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.021516   sd:  17%
# (np.int64(2), '3D', 'L_refined', 'S', 'Mass')  reminder: 0.001321   sd:  53%
# (np.int64(2), '3D', 'L_refined', 'S', 'Sources')  reminder: 0.00097351 sd:   3%
# (np.int64(2), '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0036569  sd:  80%
# (np.int64(2), '3D', 'L_uniform', 'L', 'Mass')  reminder: 0.093649   sd:   1%
# (np.int64(2), '3D', 'L_uniform', 'L', 'Sources')  reminder: 0.092571   sd:   1%
# (np.int64(2), '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.19336    sd:   6%
# (np.int64(2), '3D', 'L_uniform', 'M', 'Mass')  reminder: 0.010242   sd:  17%
# (np.int64(2), '3D', 'L_uniform', 'M', 'Sources')  reminder: 0.010005   sd:  22%
# (np.int64(2), '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.022004   sd:  19%
# (np.int64(2), '3D', 'L_uniform', 'S', 'Mass')  reminder: 0.0012573  sd:  53%
# (np.int64(2), '3D', 'L_uniform', 'S', 'Sources')  reminder: 0.00091582 sd:   4%
# (np.int64(2), '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0035264  sd:  81%
# (np.int64(3), '2D', 'B_refined', 'L', 'Mass')  reminder: 0.085719   sd:   5%
# (np.int64(3), '2D', 'B_refined', 'L', 'Sources')  reminder: 0.085365   sd:   2%
# (np.int64(3), '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.13632    sd:   4%
# (np.int64(3), '2D', 'B_refined', 'M', 'Mass')  reminder: 0.0086159  sd:   8%
# (np.int64(3), '2D', 'B_refined', 'M', 'Sources')  reminder: 0.0082485  sd:   1%
# (np.int64(3), '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.014653   sd:  24%
# (np.int64(3), '2D', 'B_refined', 'S', 'Mass')  reminder: 0.0011865  sd:  54%
# (np.int64(3), '2D', 'B_refined', 'S', 'Sources')  reminder: 0.00086637 sd:   6%
# (np.int64(3), '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0029435  sd:  94%
# (np.int64(3), '2D', 'B_uniform', 'L', 'Mass')  reminder: 0.085775   sd:   4%
# (np.int64(3), '2D', 'B_uniform', 'L', 'Sources')  reminder: 0.086297   sd:   4%
# (np.int64(3), '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.13582    sd:   6%
# (np.int64(3), '2D', 'B_uniform', 'M', 'Mass')  reminder: 0.0088315  sd:   9%
# (np.int64(3), '2D', 'B_uniform', 'M', 'Sources')  reminder: 0.008454   sd:   1%
# (np.int64(3), '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.015032   sd:  21%
# (np.int64(3), '2D', 'B_uniform', 'S', 'Mass')  reminder: 0.0012289  sd:  53%
# (np.int64(3), '2D', 'B_uniform', 'S', 'Sources')  reminder: 0.00089604 sd:   4%
# (np.int64(3), '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0029787  sd:  95%
# (np.int64(3), '2D', 'L_refined', 'L', 'Mass')  reminder: 0.088434   sd:   3%
# (np.int64(3), '2D', 'L_refined', 'L', 'Sources')  reminder: 0.089076   sd:   5%
# (np.int64(3), '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.14094    sd:   6%
# (np.int64(3), '2D', 'L_refined', 'M', 'Mass')  reminder: 0.0085786  sd:  11%
# (np.int64(3), '2D', 'L_refined', 'M', 'Sources')  reminder: 0.0082094  sd:   1%
# (np.int64(3), '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.014741   sd:  23%
# (np.int64(3), '2D', 'L_refined', 'S', 'Mass')  reminder: 0.0011642  sd:  57%
# (np.int64(3), '2D', 'L_refined', 'S', 'Sources')  reminder: 0.00082828 sd:   6%
# (np.int64(3), '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0028878  sd:  98%
# (np.int64(3), '2D', 'L_uniform', 'L', 'Mass')  reminder: 0.08493    sd:   4%
# (np.int64(3), '2D', 'L_uniform', 'L', 'Sources')  reminder: 0.084005   sd:   2%
# (np.int64(3), '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.13459    sd:   5%
# (np.int64(3), '2D', 'L_uniform', 'M', 'Mass')  reminder: 0.0088404  sd:  11%
# (np.int64(3), '2D', 'L_uniform', 'M', 'Sources')  reminder: 0.0085263  sd:   4%
# (np.int64(3), '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.015163   sd:  24%
# (np.int64(3), '2D', 'L_uniform', 'S', 'Mass')  reminder: 0.0011812  sd:  56%
# (np.int64(3), '2D', 'L_uniform', 'S', 'Sources')  reminder: 0.00083692 sd:   5%
# (np.int64(3), '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.002898   sd:  97%
# (np.int64(3), '3D', 'B_refined', 'L', 'Mass')  reminder: 0.091967   sd:   4%
# (np.int64(3), '3D', 'B_refined', 'L', 'Sources')  reminder: 0.090959   sd:   3%
# (np.int64(3), '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.20387    sd:   8%
# (np.int64(3), '3D', 'B_refined', 'M', 'Mass')  reminder: 0.0095508  sd:  13%
# (np.int64(3), '3D', 'B_refined', 'M', 'Sources')  reminder: 0.0092047  sd:  10%
# (np.int64(3), '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.021674   sd:  17%
# (np.int64(3), '3D', 'B_refined', 'S', 'Mass')  reminder: 0.0013273  sd:  53%
# (np.int64(3), '3D', 'B_refined', 'S', 'Sources')  reminder: 0.00097837 sd:   6%
# (np.int64(3), '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0037047  sd:  79%
# (np.int64(3), '3D', 'B_uniform', 'L', 'Mass')  reminder: 0.094327   sd:   4%
# (np.int64(3), '3D', 'B_uniform', 'L', 'Sources')  reminder: 0.093635   sd:   3%
# (np.int64(3), '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.19811    sd:   2%
# (np.int64(3), '3D', 'B_uniform', 'M', 'Mass')  reminder: 0.0099139  sd:  10%
# (np.int64(3), '3D', 'B_uniform', 'M', 'Sources')  reminder: 0.0095092  sd:   2%
# (np.int64(3), '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.022062   sd:  16%
# (np.int64(3), '3D', 'B_uniform', 'S', 'Mass')  reminder: 0.0014385  sd:  48%
# (np.int64(3), '3D', 'B_uniform', 'S', 'Sources')  reminder: 0.0010871  sd:   6%
# (np.int64(3), '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0039152  sd:  76%
# (np.int64(3), '3D', 'L_refined', 'L', 'Mass')  reminder: 0.093873   sd:   2%
# (np.int64(3), '3D', 'L_refined', 'L', 'Sources')  reminder: 0.092029   sd:   2%
# (np.int64(3), '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.20634    sd:   4%
# (np.int64(3), '3D', 'L_refined', 'M', 'Mass')  reminder: 0.0097088  sd:  10%
# (np.int64(3), '3D', 'L_refined', 'M', 'Sources')  reminder: 0.0092575  sd:   1%
# (np.int64(3), '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.022107   sd:  17%
# (np.int64(3), '3D', 'L_refined', 'S', 'Mass')  reminder: 0.0013568  sd:  54%
# (np.int64(3), '3D', 'L_refined', 'S', 'Sources')  reminder: 0.00099998 sd:   7%
# (np.int64(3), '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0037881  sd:  80%
# (np.int64(3), '3D', 'L_uniform', 'L', 'Mass')  reminder: 0.094423   sd:   5%
# (np.int64(3), '3D', 'L_uniform', 'L', 'Sources')  reminder: 0.09294    sd:   1%
# (np.int64(3), '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.19708    sd:   6%
# (np.int64(3), '3D', 'L_uniform', 'M', 'Mass')  reminder: 0.010059   sd:   9%
# (np.int64(3), '3D', 'L_uniform', 'M', 'Sources')  reminder: 0.0096152  sd:   2%
# (np.int64(3), '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.022087   sd:  20%
# (np.int64(3), '3D', 'L_uniform', 'S', 'Mass')  reminder: 0.001277   sd:  55%
# (np.int64(3), '3D', 'L_uniform', 'S', 'Sources')  reminder: 0.00093427 sd:   6%
# (np.int64(3), '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0035919  sd:  81%
#       run_id size dim    n_el field_variant assembly_variant assembly_class  \
# 0          0    L  2D  304838         model     FullAssembly           Mass
# 1          0    L  2D  304838         model     ComputeLocal           Mass
# 2          0    L  2D  304838         const       EvalFields           Mass
# 3          0    L  2D  304838         model       EvalFields           Mass
# 4          0    L  2D  304838         model     FullAssembly           Mass
# ...      ...  ...  ..     ...           ...              ...            ...
# 7771       3    S  3D    2889         const       EvalFields      Stiffness
# 7772       3    S  3D    2889         model       EvalFields      Stiffness
# 7773       3    S  3D    2889         model     ComputeLocal      Stiffness
# 7774       3    S  3D    2889         model     FullAssembly      Stiffness
# 7775       3    S  3D    2889         model     FullAssembly      Stiffness
#
#                  tag  n_calls integral_type      time  time_fraction  \
# 0       colect_patch  1219352                0.220138       0.087525
# 1       colect_patch  1219352                0.218758       0.097199
# 2       colect_patch  1219352                0.218713       0.241463
# 3       colect_patch  1219352                0.222210       0.172251
# 4       create_patch    12320                0.106573       0.042373
# ...              ...      ...           ...       ...            ...
# 7771    dimjoin_loop      696       dimjoin  0.000046       0.000385
# 7772    dimjoin_loop      696       dimjoin  0.000038       0.000185
# 7773   dimjoin_local      696       dimjoin  0.000003       0.000119
# 7774  dimjoin_global      696       dimjoin -0.000002       0.000102
# 7775        reminder        4                0.003592       0.816429
#
#       time_fraction_of_reminder         parent_tag  level  mesh_type
# 0                           NaN       MassAssembly      9  B_refined
# 1                           NaN       MassAssembly      9  B_refined
# 2                           NaN       MassAssembly      9  B_refined
# 3                           NaN       MassAssembly      9  B_refined
# 4                           NaN       MassAssembly      9  B_refined
# ...                         ...                ...    ...        ...
# 7771                        NaN  StiffnessAssembly      9  L_uniform
# 7772                        NaN  StiffnessAssembly      9  L_uniform
# 7773                        NaN  StiffnessAssembly      9  L_uniform
# 7774                        NaN  StiffnessAssembly      9  L_uniform
# 7775                   0.010022           assembly      8  L_uniform
#
# [7776 rows x 16 columns]

# %%
ddf = detail_df.copy()
ddf['dim_size'] = ddf['dim'] + '_' + ddf['size']
ddf['time'] = ddf['time'] / ddf['n_el']
#ddf.set_index(['assembly_class'], inplace=True)
#print(ddf.columns)
#print(detail_df['assembly_class'])

# Define custom colors matching structure of `dim_size` values
cold_tones = ['#5F3EA0', '#6495ED', '#00CED1'] 
warm_tones = ['#a42d14', '#ff5308', '#f0f03a', ] 
custom_palette = cold_tones + warm_tones
sns.set_palette(custom_palette)

facet_grid = sns.catplot(data=ddf, x='time', y='tag', hue='dim_size', row='assembly_class',
            kind='strip', orient='h', sharex=False, aspect=2, jitter=0.25, size=3,
            row_order=['Stiffness', 'Mass', 'Sources'],
            legend_out=False)

handles, labels = facet_grid.axes[2][0].get_legend_handles_labels()
#print(handles, labels)
for ax, loc in zip(facet_grid.axes.flatten(), [1,4,4]):
    ax.legend(handles, labels, loc=loc)
facet_grid.axes[2][0].set_xlabel("Time per element")
facet_grid.fig.subplots_adjust(top=0.93) # adjust the Figure in rp
facet_grid.fig.suptitle(f'Detailed view of: {flow123d_version}')

plt.savefig("detailed_plot.pdf")

# %% [markdown]
# ## Interpretation
#
# ### Patch creation
# - patch creation overhead is relatively small, comparable to field_model evaluation for matrix assemblies
# - the overhead is much more significant for simple assembly like `Sources`
# - the overhead in field evaluation and field access is not included, so in fact, the overhead could be higher 1.5 times
#
# ### Field evaluation
# - It seems that evaluation of tensor-valued fields necessary in `Stiffness` is much more costly. Also, different kinds of fields are possibly in use.
# - Constant value fields have negligible evaluation time.
#
# ### Assembly
# - `<integral>_global` are calculated from noisy `<integral>_local` values, so it is noisy as well, leading to even negative values for fast vector-only assembly of `Sources`.
# - Nevertheless, it is relatively costly for `Stiffness` and clearly correlated to the number of calls since it is higher for 3d meshes.
# - Local evaluations are the highest in all three cases. Probably dominated by `FEValues.reinit` (according to VTUNE analysis).
