# %% [markdown]
# # Extract dataframe
#
# In order to mimick dg_transport, benchmark use zero_time_step and 4 calls of update_solution.
# Therefore initially there were two items for every group. One with n_calls==1 (zero_time_step)
# and one with n_calls=4 (4 x update_solution). The loading script has been hacked to skip "ZERO-TIME STEP" tag
# However all tags excepting "full_mesh" are called in 4 assembly loops.

# %%
#print(profiler_files)

# %%
# zip archive or pattern
# TODO: parametrize by assembly class names ?
profiler_files="dg_asm.zip"
profiler_files="24_10_21_elasticity_asm.zip"
#profiler_files="../../../bin/benchmark/dg_asm-1-bench_profiler_*.json"

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
import dg_asm_bench_postprocess as bp

# load and process Profiler JSON output
df_orig = df = bp.load_profiler_data(profiler_files)

from IPython.display import Markdown, display
    
def table_overview(df):
    for col in df.columns:
        unique = df[col].unique()
        is_factor =  all([type(v) is str for v in unique])
        value_set = np.sort(unique)
        np.set_printoptions(threshold=30)
        value_set = np.array2string(value_set, precision=2, separator=',')
        display(Markdown(f'**{col}**: {value_set}'))
                

table_overview(df_orig)
# Out:
# Input profiler files:  [Path('24_10_21_elasticity_asm.zip', 'elasticity_asm-1-bench_profiler_1.json'), Path('24_10_21_elasticity_asm.zip', 'elasticity_asm-1-bench_profiler_2.json'), Path('24_10_21_elasticity_asm.zip', 'elasticity_asm-1-bench_profiler_3.json'), Path('24_10_21_elasticity_asm.zip', 'elasticity_asm-1-bench_profiler_4.json')]
# **branch**: ['DF_patch_fe_mechanics']
# **commit**: ['c13f069']
# **run_id**: [0,1,2,3]
# **domain_shape**: ['B','L']
# **mesh_size**: ['L','M','S']
# **spacedim**: ['2D','3D']
# **uniformity**: ['refined','uniform']
# **n_mesh_elements**: [  2770.,  2806.,  2889.,  2918.,  3041.,  3046.,  3049.,  3392., 29250.,
#   29346., 30046., 30168., 30186., 30574., 31423., 31914.,301689.,302320.,
#  304838.,305121.,305984.,308574.,310479.,316110.]
# **n_repeats**: [ 1,10]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Rhs','Stiffness']
# **tag**: ['RhsAssembly','StiffnessAssembly','add_integrals_to_patch',
#  'assemble_fluxes_boundary','assemble_fluxes_elem_elem',
#  'assemble_fluxes_elem_side','assemble_volume_integrals','cache_update',
#  'create_patch','full_mesh','patch_reinit']
# **number_of_calls**: [      1,      4,     10,...,1249736,1257508,1266180]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [6.23e-05,6.24e-05,6.25e-05,...,5.66e+01,5.68e+01,5.74e+01]
# **time_fraction**: [4.73e-05,4.76e-05,4.78e-05,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0.01,0.01,0.01,...,0.08,0.1 , nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MECH-ONE STEP','RhsAssembly','StiffnessAssembly']
# **level**: [5,7,8]

# %% [markdown]
# # Basic dataset modifications
# - rename some columns
# - extract `branch` and `commit` columns into `flow123d_version` variable, drop these columns
# - fix `n_el` type
# - merge `shape` and `uniformity` columns
# - Divide 'time' and 'number_of_calls' by 'n_repeats'

# %%
# Get benchmarked sources version.
df = df_orig.copy()
assert df['branch'].nunique() == 1
assert df['commit'].nunique() == 1
flow123d_version = f"{df['branch'].loc[0]}_{df['commit'].loc[0]}"
print("Benchmarked Flow123d version: ", flow123d_version)
df.drop(columns=["branch", "commit"], inplace=True)

# rename some columns:
col_map = dict(spacedim='dim', mesh_size='size', domain_shape='shape', n_mesh_elements='n_el', 
               number_of_calls='n_calls')
df.rename(columns=col_map, inplace=True)

# int values for 'n_el', 'n_calls' columns
df['n_el'] = df['n_el'].astype(int)

# merge mesh shape and uniformity
df['mesh_type'] = [f"{row['shape']}_{row['uniformity']}" for index, row in df.iterrows()]
df.drop(columns=["shape", "uniformity"], inplace=True)

def apply_n_repeats(df):
    repeated_cols = ['n_calls', 'time']
    for c in repeated_cols:
        df[c] /= df['n_repeats']
    df['n_calls'] = df['n_calls'].astype(int)
    df.drop(columns=['n_repeats'], inplace=True)
    return df

df = apply_n_repeats(df)


table_overview(df)
# Out:
# Benchmarked Flow123d version:  DF_patch_fe_mechanics_c13f069
# **run_id**: [0,1,2,3]
# **size**: ['L','M','S']
# **dim**: ['2D','3D']
# **n_el**: [  2770,  2806,  2889,  2918,  3041,  3046,  3049,  3392, 29250, 29346,
#   30046, 30168, 30186, 30574, 31423, 31914,301689,302320,304838,305121,
#  305984,308574,310479,316110]
# **field_variant**: ['const','model']
# **assembly_variant**: ['ComputeLocal','EvalFields','FullAssembly']
# **assembly_class**: ['','Rhs','Stiffness']
# **tag**: ['RhsAssembly','StiffnessAssembly','add_integrals_to_patch',
#  'assemble_fluxes_boundary','assemble_fluxes_elem_elem',
#  'assemble_fluxes_elem_side','assemble_volume_integrals','cache_update',
#  'create_patch','full_mesh','patch_reinit']
# **n_calls**: [      1,      4,    124,...,1249736,1257508,1266180]
# **integral_type**: ['','boundary_side','cell','dimjoin','edge']
# **time**: [6.42e-06,6.44e-06,6.46e-06,...,5.66e+01,5.68e+01,5.74e+01]
# **time_fraction**: [4.73e-05,4.76e-05,4.78e-05,...,1.00e+00,1.00e+00,1.00e+00]
# **time_fraction_of_reminder**: [0.01,0.01,0.01,...,0.08,0.1 , nan]
# **parent_tag**: ['ComputeLocal_model','EvalFields_const','EvalFields_model',
#  'FullAssembly_model','MECH-ONE STEP','RhsAssembly','StiffnessAssembly']
# **level**: [5,7,8]
# **mesh_type**: ['B_refined','B_uniform','L_refined','L_uniform']

# %% [markdown]
# # Mesh times comparison
# - plot `full_mesh` time for mesh and run ID variants.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def mesh_cases_plot(df, time_label):
    cases_cols = ['dim_size', 'mesh_type', 'run_id', 'variant']
    stacked_df = df.groupby(cases_cols)['time'].sum().unstack('variant').fillna(0)
    n_rows = len(stacked_df)
    
    # for grouping by position on Y axis
    level_labels = [l for l in stacked_df.index.levels]
    level_vals = [pd.Categorical(l).codes for l in stacked_df.index.levels]
    int_df = stacked_df.copy()
    int_df.index = stacked_df.index.set_levels(level_vals, level=[0, 1, 2])

    bar_width = 0.5
    steps = []
    ticks = []
    tick_labels = []
    last_idx = (0,-1,-1)
    step = np.array([0.5, 0.5, bar_width])
    for idx in int_df.index.drop_duplicates():
        diff = np.array(idx) - np.array(last_idx)
        last_idx = idx
        if diff[1] != 0:
            ticks.append(len(steps))
            tick_labels.append(f'{level_labels[0][idx[0]]}, {level_labels[1][idx[1]]: >12}')
        steps.append(np.sum(step[diff != 0]))
        
    positions = np.cumsum(steps)
    ticks = positions[ticks]        
    
    # Initialize a color palette
    palette = sns.color_palette("tab10", len(stacked_df.columns))
    
    # Plotting
    fig, ax = plt.subplots(figsize=(10, 6))
  
    # Create stacked bars
    bottom = np.zeros(n_rows)
    for j, col in enumerate(stacked_df.columns):
            ax.barh(positions, stacked_df[col], bar_width, left=bottom, color=palette[j], label=col)
            bottom += stacked_df[col]
    
    ax.set_yticks(ticks)
    ax.set_yticklabels(tick_labels)
    ax.legend(title='Assembly Variants')
    ax.set_xlabel(time_label)
    ax.set_ylabel('Mesh variants: dim_size, shape_refine')
    ax.set_title(f'Overview of benchmark: {flow123d_version}')
    
    # Display
    fig.tight_layout()
    plt.show()
    return fig
    

df_sumrun = df[df['tag'] == 'full_mesh'].copy()
df_sumrun['dim_size'] = df_sumrun['dim'] + '_' + df_sumrun['size']
def variant(row):
    var = row['assembly_variant']
    if var == 'EvalFields':
        var = f"Fields_{row['field_variant']}"
    return var

df_sumrun['variant'] = df.apply(variant, axis=1)
fig = mesh_cases_plot(df_sumrun, 'Time [s]')

# %% [markdown]
# ## Relative Mesh comparison
# Comparison of time per element allows us to see:
#
# - nearly no difference between mesh sizes, i.e., almost zero assembly overhead or
#   additional 'fit to the cache' advantages of small meshes.
#   Fitting all to the cache probably could not happen as individual data are allocated at different places.
#   It seems more probable that even for small meshes (S ~ 1000 elements)
#   the calculation has some cache misses. Needs better investigation.
#
# - significant impact of 3D calculation. 3D has about 4/3 times more DOFs, the increase is slightly higher,
#   possibly due to a larger increase in the number of quadrature points o
#
# - very small impact of `mesh_type`
#
# - the significant impact of `run_id` we should rather increase the number of runs to 5. Memory layout could
#   have some impact. Ideally, we should minimize this impact by own arena allocator used for
#   assembly structures on the patch.

# %%
df_reltime = df_sumrun.copy()
df_reltime['time'] = df_reltime['time'] / df_reltime['n_el'] * 1000
fig = mesh_cases_plot(df_reltime, 'Time per 1000 element [s]')
fig.savefig("overview_plot.pdf")

# %% [markdown]
# # Aggregate runs
# - compute suitable position and variance indicators
# - report (tags) with high variability and high time fraction
#
# Se that there is much higher `run_ID` variability at a detailed level and even for long time frames.

# %%
index_cols = ['dim', 'mesh_type', 'size', 'assembly_variant', 'field_variant', 'assembly_class', 'integral_type', 'tag']
grouped = df.groupby(index_cols)
#print(grouped.size())
n_runs = len(df['run_id'].unique())
assert all(grouped.size() == n_runs)
# Available groups
# print(grouped.groups.keys())
# Rows in a single group:
# display(grouped.get_group(('2D', 'B_refined', 'L', 'ComputeLocal', 'model', 'Mass', '', 'MassAssembly')))

def get_median_row(group):
    min_t = group['time'].min()
    median_t = group['time'].median()
    max_t = group['time'].max()
    row = group[group['time'] == min_t]
    row['Err'] = (median_t - min_t) / min_t
    return row

# Apply the custom function to each group
df_med = grouped.apply(get_median_row).reset_index(drop=True)
#display(result)
df_med.drop(columns=['run_id'], inplace=True)
df_med.drop(columns=['n_calls', 'integral_type', 'n_el', 'time_fraction_of_reminder', 'parent_tag', 'level'], inplace=True)

# Sort the DataFrame by column 'A'
# There are many items with big error and big time fraction.
sorted_df = df_med.sort_values(by='Err', ascending=False)
big_err = sorted_df[sorted_df['Err'] > 0.1]
big_err_and_fraction = big_err[big_err['time_fraction'] > 0.05]
# Display the sorted DataFrame
display(big_err_and_fraction.head(30))


# Result kee run_id and try to plot all three values in plots.
# Out:
# Empty DataFrame
# Columns: [size, dim, field_variant, assembly_variant, assembly_class, tag, time, time_fraction, mesh_type, Err]
# Index: []

# %% [markdown]
# # Detailed view
#
# 1. reduce assembly variants to new tags having complete decomposition of a single assembly
# 2. separate plot for each `assembly_class`
# 3. group by:
#    `dim_size`, `tag`
# 4. in every group points from: reduction, runs, mesh_type `

# %%
# reduce columns: assembly_variant, field_variant, integral_type
# to tags: 
# field_const, field_model
# <integral>_loop, <integral>_local, <integral>_global
# reminder (of assembly)

new_rows = {}

def add_row(group, orig_row_mask, tag, time_subtrack):
    """
    Add new row to the dataset by taking `orig_row_mask` from `group`
    setting the `tag` and subtrack `time_subtrack` from the `time` column.
    We return original `time` value.
    """
    orig = group[orig_row_mask].to_dict('list')
    orig_time = np.mean(orig['time'])
    for i in range(len(orig['time'])):
        #print(new_row)
        orig['time'][i] -= time_subtrack
        orig['tag'][i] = tag
    for key, item_dict in orig.items():
        col = new_rows.setdefault(key, [])
        col.extend(item_dict)
    return orig_time
    

# check same time of some tags between variants
index_cols = ['run_id', 'dim', 'mesh_type', 'size',  'assembly_class']
grouped = df.groupby(index_cols)

# Add column with assembly total times
#
for name, group in grouped:
    # skip full_mesh group
    if name[-1] == '':
        assert all(group['tag'] == 'full_mesh')
        continue
    main_tag = f"{name[-1]}Assembly"
    asm_var = group['assembly_variant']    
    field_var = group['field_variant']
    tags = group['tag']
    integral = group['integral_type']

    # compute reminders
    reminders = {
        'field_const':('EvalFields', 'const'),
        'field_model':('EvalFields', 'model'),
        'local': ('ComputeLocal', 'model'),
        'global': ('FullAssembly', 'model'),}
    rm = {}
    for key, (av, fv) in reminders.items():
        subgroup = group[(asm_var == av) & (field_var == fv)]
        assembly_time = subgroup[subgroup['tag'] == main_tag]['time'].item()
        total = np.sum(subgroup['time']) - assembly_time
        reminder = assembly_time - total
        rm[key] = reminder #, reminder/total)
    rm_mean = np.mean(list(rm.values()))
    rm_std = np.std(list(rm.values()))
    print(f"{repr(name):<40}  reminder: {rm_mean:<10.5} sd: {300*rm_std/rm_mean:3.0f}%")
            
    
    # Patch creation
    add_row(group, tags == 'add_integrals_to_patch', 'colect_patch', 0.0)
    add_row(group, tags == 'create_patch', 'create_patch', 0.0)
    # Fields - Cache Update
    field_const_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'const')
    t_field_const = add_row(group, field_const_mask, 'field_const', 0.0)
    field_model_mask = (asm_var == 'EvalFields') & (tags == 'cache_update') & (field_var == 'model')
    add_row(group, field_model_mask, 'field_model',  t_field_const)

    # Assembly integrals
    for it in integral.unique():
        if it == '':
            continue
        loop_mask = (asm_var == 'EvalFields') & (integral == it)
        t_loop = add_row(group, loop_mask, f'{it}_loop', 0.0)
        local_mask = (asm_var == 'ComputeLocal') & (integral == it)
        t_local = add_row(group, local_mask, f'{it}_local', t_loop)
        global_mask = (asm_var == 'FullAssembly') & (integral == it)
        add_row(group, global_mask, f'{it}_global', t_local)
    
    # Reminder - taking mean value, bute there could be huge deviances, but mostly for small values    
    assembly_mask = (asm_var == 'FullAssembly') & (tags == main_tag)
    mod_group = group[assembly_mask].copy()
    mod_group['time'] = rm_mean
    add_row(mod_group, mod_group['time'] == mod_group['time'], 'reminder', 0.0)
    
detail_df = pd.DataFrame(new_rows)
#table_overview(detail_df)
display(detail_df)
# Out:
# (0, '2D', 'B_refined', 'L', 'Rhs')        reminder: 0.10537    sd:   7%
# (0, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.1053     sd:   2%
# (0, '2D', 'B_refined', 'M', 'Rhs')        reminder: 0.010482   sd:  10%
# (0, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.011062   sd:  25%
# (0, '2D', 'B_refined', 'S', 'Rhs')        reminder: 0.0013887  sd:  44%
# (0, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0014015  sd:  41%
# (0, '2D', 'B_uniform', 'L', 'Rhs')        reminder: 0.10393    sd:   5%
# (0, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.10611    sd:   2%
# (0, '2D', 'B_uniform', 'M', 'Rhs')        reminder: 0.010687   sd:   8%
# (0, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.012956   sd:  78%
# (0, '2D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0014003  sd:  43%
# (0, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0014187  sd:  39%
# (0, '2D', 'L_refined', 'L', 'Rhs')        reminder: 0.109      sd:   6%
# (0, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.11006    sd:   4%
# (0, '2D', 'L_refined', 'M', 'Rhs')        reminder: 0.010566   sd:  11%
# (0, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.010737   sd:   7%
# (0, '2D', 'L_refined', 'S', 'Rhs')        reminder: 0.0013443  sd:  47%
# (0, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0013522  sd:  45%
# (0, '2D', 'L_uniform', 'L', 'Rhs')        reminder: 0.10319    sd:   5%
# (0, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.10502    sd:   2%
# (0, '2D', 'L_uniform', 'M', 'Rhs')        reminder: 0.010754   sd:  10%
# (0, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.010931   sd:   8%
# (0, '2D', 'L_uniform', 'S', 'Rhs')        reminder: 0.0013343  sd:  47%
# (0, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0013424  sd:  44%
# (0, '3D', 'B_refined', 'L', 'Rhs')        reminder: 0.13388    sd:   5%
# (0, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.13866    sd:   5%
# (0, '3D', 'B_refined', 'M', 'Rhs')        reminder: 0.014316   sd:  19%
# (0, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.014573   sd:  17%
# (0, '3D', 'B_refined', 'S', 'Rhs')        reminder: 0.0017641  sd:  41%
# (0, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0017805  sd:  37%
# (0, '3D', 'B_uniform', 'L', 'Rhs')        reminder: 0.11884    sd:   5%
# (0, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12025    sd:   6%
# (0, '3D', 'B_uniform', 'M', 'Rhs')        reminder: 0.012945   sd:  12%
# (0, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.013005   sd:   6%
# (0, '3D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0018307  sd:  36%
# (0, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0018427  sd:  34%
# (0, '3D', 'L_refined', 'L', 'Rhs')        reminder: 0.12951    sd:   5%
# (0, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.13293    sd:   6%
# (0, '3D', 'L_refined', 'M', 'Rhs')        reminder: 0.013439   sd:  12%
# (0, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013713   sd:   9%
# (0, '3D', 'L_refined', 'S', 'Rhs')        reminder: 0.0017553  sd:  44%
# (0, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0017556  sd:  41%
# (0, '3D', 'L_uniform', 'L', 'Rhs')        reminder: 0.11865    sd:   5%
# (0, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.11988    sd:   3%
# (0, '3D', 'L_uniform', 'M', 'Rhs')        reminder: 0.013274   sd:   5%
# (0, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.013426   sd:   9%
# (0, '3D', 'L_uniform', 'S', 'Rhs')        reminder: 0.001644   sd:  41%
# (0, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0016581  sd:  37%
# (1, '2D', 'B_refined', 'L', 'Rhs')        reminder: 0.10362    sd:   3%
# (1, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.10614    sd:   5%
# (1, '2D', 'B_refined', 'M', 'Rhs')        reminder: 0.010555   sd:   7%
# (1, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.010667   sd:   7%
# (1, '2D', 'B_refined', 'S', 'Rhs')        reminder: 0.0013914  sd:  40%
# (1, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0013983  sd:  41%
# (1, '2D', 'B_uniform', 'L', 'Rhs')        reminder: 0.10374    sd:   3%
# (1, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.10606    sd:   1%
# (1, '2D', 'B_uniform', 'M', 'Rhs')        reminder: 0.010721   sd:   6%
# (1, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.01092    sd:   8%
# (1, '2D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0014072  sd:  43%
# (1, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0014156  sd:  40%
# (1, '2D', 'L_refined', 'L', 'Rhs')        reminder: 0.10884    sd:   4%
# (1, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.11056    sd:   3%
# (1, '2D', 'L_refined', 'M', 'Rhs')        reminder: 0.010652   sd:  12%
# (1, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.010726   sd:   8%
# (1, '2D', 'L_refined', 'S', 'Rhs')        reminder: 0.0013364  sd:  45%
# (1, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0013522  sd:  44%
# (1, '2D', 'L_uniform', 'L', 'Rhs')        reminder: 0.10271    sd:   3%
# (1, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.10532    sd:   4%
# (1, '2D', 'L_uniform', 'M', 'Rhs')        reminder: 0.010851   sd:  10%
# (1, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.011108   sd:   4%
# (1, '2D', 'L_uniform', 'S', 'Rhs')        reminder: 0.0013394  sd:  45%
# (1, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0013455  sd:  42%
# (1, '3D', 'B_refined', 'L', 'Rhs')        reminder: 0.13529    sd:   3%
# (1, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.139      sd:   3%
# (1, '3D', 'B_refined', 'M', 'Rhs')        reminder: 0.013716   sd:   9%
# (1, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.01426    sd:  11%
# (1, '3D', 'B_refined', 'S', 'Rhs')        reminder: 0.0017822  sd:  43%
# (1, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0017937  sd:  37%
# (1, '3D', 'B_uniform', 'L', 'Rhs')        reminder: 0.11845    sd:   3%
# (1, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12067    sd:   4%
# (1, '3D', 'B_uniform', 'M', 'Rhs')        reminder: 0.012878   sd:   8%
# (1, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.01301    sd:   8%
# (1, '3D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0018383  sd:  37%
# (1, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0018461  sd:  34%
# (1, '3D', 'L_refined', 'L', 'Rhs')        reminder: 0.13133    sd:  11%
# (1, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.13275    sd:   4%
# (1, '3D', 'L_refined', 'M', 'Rhs')        reminder: 0.013323   sd:   7%
# (1, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013974   sd:   2%
# (1, '3D', 'L_refined', 'S', 'Rhs')        reminder: 0.0017072  sd:  41%
# (1, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0017272  sd:  37%
# (1, '3D', 'L_uniform', 'L', 'Rhs')        reminder: 0.11946    sd:   2%
# (1, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.12017    sd:   4%
# (1, '3D', 'L_uniform', 'M', 'Rhs')        reminder: 0.013173   sd:  10%
# (1, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.013362   sd:   9%
# (1, '3D', 'L_uniform', 'S', 'Rhs')        reminder: 0.0016605  sd:  43%
# (1, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0016714  sd:  39%
# (2, '2D', 'B_refined', 'L', 'Rhs')        reminder: 0.10385    sd:   2%
# (2, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.10635    sd:   1%
# (2, '2D', 'B_refined', 'M', 'Rhs')        reminder: 0.010527   sd:   9%
# (2, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.010734   sd:   9%
# (2, '2D', 'B_refined', 'S', 'Rhs')        reminder: 0.0014186  sd:  47%
# (2, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0014192  sd:  42%
# (2, '2D', 'B_uniform', 'L', 'Rhs')        reminder: 0.10355    sd:   2%
# (2, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.10628    sd:   4%
# (2, '2D', 'B_uniform', 'M', 'Rhs')        reminder: 0.010721   sd:   8%
# (2, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.010988   sd:  11%
# (2, '2D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0014159  sd:  44%
# (2, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0014287  sd:  42%
# (2, '2D', 'L_refined', 'L', 'Rhs')        reminder: 0.10935    sd:   6%
# (2, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.11036    sd:   4%
# (2, '2D', 'L_refined', 'M', 'Rhs')        reminder: 0.010638   sd:  16%
# (2, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.010646   sd:   8%
# (2, '2D', 'L_refined', 'S', 'Rhs')        reminder: 0.0013353  sd:  45%
# (2, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0013518  sd:  43%
# (2, '2D', 'L_uniform', 'L', 'Rhs')        reminder: 0.10266    sd:   3%
# (2, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.10531    sd:   3%
# (2, '2D', 'L_uniform', 'M', 'Rhs')        reminder: 0.01077    sd:   8%
# (2, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.01095    sd:   9%
# (2, '2D', 'L_uniform', 'S', 'Rhs')        reminder: 0.0013372  sd:  46%
# (2, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0013554  sd:  44%
# (2, '3D', 'B_refined', 'L', 'Rhs')        reminder: 0.13557    sd:   5%
# (2, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.13874    sd:   4%
# (2, '3D', 'B_refined', 'M', 'Rhs')        reminder: 0.013779   sd:   8%
# (2, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.014291   sd:   9%
# (2, '3D', 'B_refined', 'S', 'Rhs')        reminder: 0.0018698  sd:  45%
# (2, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0018971  sd:  43%
# (2, '3D', 'B_uniform', 'L', 'Rhs')        reminder: 0.11839    sd:   2%
# (2, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12234    sd:   8%
# (2, '3D', 'B_uniform', 'M', 'Rhs')        reminder: 0.012795   sd:   7%
# (2, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.013013   sd:  10%
# (2, '3D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0018928  sd:  40%
# (2, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0018927  sd:  36%
# (2, '3D', 'L_refined', 'L', 'Rhs')        reminder: 0.12939    sd:   4%
# (2, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.1323     sd:   4%
# (2, '3D', 'L_refined', 'M', 'Rhs')        reminder: 0.013293   sd:   8%
# (2, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013691   sd:  11%
# (2, '3D', 'L_refined', 'S', 'Rhs')        reminder: 0.0017097  sd:  41%
# (2, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0017276  sd:  39%
# (2, '3D', 'L_uniform', 'L', 'Rhs')        reminder: 0.11831    sd:   3%
# (2, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.12034    sd:   6%
# (2, '3D', 'L_uniform', 'M', 'Rhs')        reminder: 0.013264   sd:   6%
# (2, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.013511   sd:   9%
# (2, '3D', 'L_uniform', 'S', 'Rhs')        reminder: 0.001774   sd:  42%
# (2, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0017684  sd:  45%
# (3, '2D', 'B_refined', 'L', 'Rhs')        reminder: 0.10541    sd:   4%
# (3, '2D', 'B_refined', 'L', 'Stiffness')  reminder: 0.1058     sd:   3%
# (3, '2D', 'B_refined', 'M', 'Rhs')        reminder: 0.010424   sd:   8%
# (3, '2D', 'B_refined', 'M', 'Stiffness')  reminder: 0.01073    sd:  10%
# (3, '2D', 'B_refined', 'S', 'Rhs')        reminder: 0.0013906  sd:  43%
# (3, '2D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0014033  sd:  40%
# (3, '2D', 'B_uniform', 'L', 'Rhs')        reminder: 0.10371    sd:   3%
# (3, '2D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.10601    sd:   2%
# (3, '2D', 'B_uniform', 'M', 'Rhs')        reminder: 0.010632   sd:   8%
# (3, '2D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.010998   sd:   1%
# (3, '2D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0013999  sd:  42%
# (3, '2D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0014114  sd:  40%
# (3, '2D', 'L_refined', 'L', 'Rhs')        reminder: 0.10842    sd:   3%
# (3, '2D', 'L_refined', 'L', 'Stiffness')  reminder: 0.11013    sd:   4%
# (3, '2D', 'L_refined', 'M', 'Rhs')        reminder: 0.010911   sd:  24%
# (3, '2D', 'L_refined', 'M', 'Stiffness')  reminder: 0.011051   sd:  25%
# (3, '2D', 'L_refined', 'S', 'Rhs')        reminder: 0.0013324  sd:  46%
# (3, '2D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0013381  sd:  44%
# (3, '2D', 'L_uniform', 'L', 'Rhs')        reminder: 0.10213    sd:   2%
# (3, '2D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.10457    sd:   1%
# (3, '2D', 'L_uniform', 'M', 'Rhs')        reminder: 0.010697   sd:   9%
# (3, '2D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.010938   sd:   9%
# (3, '2D', 'L_uniform', 'S', 'Rhs')        reminder: 0.0013448  sd:  45%
# (3, '2D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0013473  sd:  44%
# (3, '3D', 'B_refined', 'L', 'Rhs')        reminder: 0.13514    sd:   5%
# (3, '3D', 'B_refined', 'L', 'Stiffness')  reminder: 0.13885    sd:   4%
# (3, '3D', 'B_refined', 'M', 'Rhs')        reminder: 0.013692   sd:   8%
# (3, '3D', 'B_refined', 'M', 'Stiffness')  reminder: 0.014116   sd:  10%
# (3, '3D', 'B_refined', 'S', 'Rhs')        reminder: 0.0017359  sd:  38%
# (3, '3D', 'B_refined', 'S', 'Stiffness')  reminder: 0.0017748  sd:  35%
# (3, '3D', 'B_uniform', 'L', 'Rhs')        reminder: 0.11828    sd:   4%
# (3, '3D', 'B_uniform', 'L', 'Stiffness')  reminder: 0.12209    sd:  10%
# (3, '3D', 'B_uniform', 'M', 'Rhs')        reminder: 0.012865   sd:   7%
# (3, '3D', 'B_uniform', 'M', 'Stiffness')  reminder: 0.013048   sd:  10%
# (3, '3D', 'B_uniform', 'S', 'Rhs')        reminder: 0.0018864  sd:  42%
# (3, '3D', 'B_uniform', 'S', 'Stiffness')  reminder: 0.0018942  sd:  35%
# (3, '3D', 'L_refined', 'L', 'Rhs')        reminder: 0.12889    sd:   4%
# (3, '3D', 'L_refined', 'L', 'Stiffness')  reminder: 0.1323     sd:   5%
# (3, '3D', 'L_refined', 'M', 'Rhs')        reminder: 0.013264   sd:  10%
# (3, '3D', 'L_refined', 'M', 'Stiffness')  reminder: 0.013591   sd:   9%
# (3, '3D', 'L_refined', 'S', 'Rhs')        reminder: 0.0016879  sd:  39%
# (3, '3D', 'L_refined', 'S', 'Stiffness')  reminder: 0.0017091  sd:  37%
# (3, '3D', 'L_uniform', 'L', 'Rhs')        reminder: 0.12005    sd:   8%
# (3, '3D', 'L_uniform', 'L', 'Stiffness')  reminder: 0.12053    sd:   5%
# (3, '3D', 'L_uniform', 'M', 'Rhs')        reminder: 0.013185   sd:   9%
# (3, '3D', 'L_uniform', 'M', 'Stiffness')  reminder: 0.013331   sd:   8%
# (3, '3D', 'L_uniform', 'S', 'Rhs')        reminder: 0.0016438  sd:  40%
# (3, '3D', 'L_uniform', 'S', 'Stiffness')  reminder: 0.0016632  sd:  38%
#       run_id size dim    n_el field_variant assembly_variant assembly_class  \
# 0          0    L  2D  304838         model     FullAssembly            Rhs
# 1          0    L  2D  304838         model     ComputeLocal            Rhs
# 2          0    L  2D  304838         const       EvalFields            Rhs
# 3          0    L  2D  304838         model       EvalFields            Rhs
# 4          0    L  2D  304838         model     FullAssembly            Rhs
# ...      ...  ...  ..     ...           ...              ...            ...
# 5179       3    S  3D    2889         const       EvalFields      Stiffness
# 5180       3    S  3D    2889         model       EvalFields      Stiffness
# 5181       3    S  3D    2889         model     ComputeLocal      Stiffness
# 5182       3    S  3D    2889         model     FullAssembly      Stiffness
# 5183       3    S  3D    2889         model     FullAssembly      Stiffness
#
#                  tag  n_calls integral_type          time  time_fraction  \
# 0       colect_patch  1221308                3.114110e-01       0.094574
# 1       colect_patch  1221308                3.266653e-01       0.100367
# 2       colect_patch  1221308                3.190934e-01       0.191467
# 3       colect_patch  1221308                3.245742e-01       0.190893
# 4       create_patch    12548                1.159032e-01       0.035199
# ...              ...      ...           ...           ...            ...
# 5179    dimjoin_loop      260       dimjoin  1.434210e-05       0.000377
# 5180    dimjoin_loop      260       dimjoin  1.443360e-05       0.000298
# 5181   dimjoin_local      260       dimjoin -1.736500e-07       0.000067
# 5182  dimjoin_global      260       dimjoin  1.792400e-06       0.000064
# 5183        reminder        4                1.663219e-03       0.765697
#
#       time_fraction_of_reminder         parent_tag  level  mesh_type
# 0                           NaN        RhsAssembly      8  B_refined
# 1                           NaN        RhsAssembly      8  B_refined
# 2                           NaN        RhsAssembly      8  B_refined
# 3                           NaN        RhsAssembly      8  B_refined
# 4                           NaN        RhsAssembly      8  B_refined
# ...                         ...                ...    ...        ...
# 5179                        NaN  StiffnessAssembly      8  L_uniform
# 5180                        NaN  StiffnessAssembly      8  L_uniform
# 5181                        NaN  StiffnessAssembly      8  L_uniform
# 5182                        NaN  StiffnessAssembly      8  L_uniform
# 5183                   0.007166      MECH-ONE STEP      7  L_uniform
#
# [5184 rows x 16 columns]

# %%
ddf = detail_df.copy()
ddf['dim_size'] = ddf['dim'] + '_' + ddf['size']
ddf['time'] = ddf['time'] / ddf['n_el']
#ddf.set_index(['assembly_class'], inplace=True)
#print(ddf.columns)
#print(detail_df['assembly_class'])

# Define custom colors matching structure of `dim_size` values
cold_tones = ['#5F3EA0', '#6495ED', '#00CED1'] 
warm_tones = ['#a42d14', '#ff5308', '#f0f03a', ] 
custom_palette = cold_tones + warm_tones
sns.set_palette(custom_palette)

assembly_classes = ddf['assembly_class'].unique()
print(assembly_classes)

facet_grid = sns.catplot(data=ddf, x='time', y='tag', hue='dim_size', row='assembly_class',
            kind='strip', orient='h', sharex=False, aspect=2, jitter=0.25, size=3,
            row_order=assembly_classes,
            legend_out=False)

handles, labels = facet_grid.axes[2][0].get_legend_handles_labels()
#print(handles, labels)
for ax, loc in zip(facet_grid.axes.flatten(), [1,4,4]):
    ax.legend(handles, labels, loc=loc)
facet_grid.axes[2][0].set_xlabel("Time per element")
facet_grid.fig.subplots_adjust(top=0.93) # adjust the Figure in rp
facet_grid.fig.suptitle(f'Detailed view of: {flow123d_version}')

plt.savefig("detailed_plot.pdf")
# Out:
# ['Rhs' 'Stiffness']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 22
#      15 print(assembly_classes)
#      17 facet_grid = sns.catplot(data=ddf, x='time', y='tag', hue='dim_size', row='assembly_class',
#      18             kind='strip', orient='h', sharex=False, aspect=2, jitter=0.25, size=3,
#      19             row_order=assembly_classes,
#      20             legend_out=False)
# ---> 22 handles, labels = facet_grid.axes[2][0].get_legend_handles_labels()
#      23 #print(handles, labels)
#      24 for ax, loc in zip(facet_grid.axes.flatten(), [1,4,4]):
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %% [markdown]
# ## Interpretation
#
# ### Patch creation
# - patch creation overhead is relatively small, comparable to field_model evaluation for matrix assemblies
# - the overhead is much more significant for simple assembly like `Sources`
# - the overhead in field evaluation and field access is not included, so in fact, the overhead could be higher 1.5 times
#
# ### Field evaluation
# - It seems that evaluation of tensor-valued fields necessary in `Stiffness` is much more costly. Also, different kinds of fields are possibly in use.
# - Constant value fields have negligible evaluation time.
#
# ### Assembly
# - `<integral>_global` are calculated from noisy `<integral>_local` values, so it is noisy as well, leading to even negative values for fast vector-only assembly of `Sources`.
# - Nevertheless, it is relatively costly for `Stiffness` and clearly correlated to the number of calls since it is higher for 3d meshes.
# - Local evaluations are the highest in all three cases. Probably dominated by `FEValues.reinit` (according to VTUNE analysis).
